# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from scipy import spatial
# %matplotlib inline

# %% [markdown]
# # Project 3: Word2Vec (70 pt)
# The goal of this project is to obtain the vector representations for words from text.
#
# The main idea is that words appearing in similar contexts have similar meanings. Because of that, word vectors of similar words should be close together. Models that use word vectors can utilize these properties, e.g., in sentiment analysis a model will learn that "good" and "great" are positive words, but will also generalize to other words that it has not seen (e.g. "amazing") because they should be close together in the vector space.
#
# Vectors can keep other language properties as well, like analogies. The question "a is to b as c is to ...?", where the answer is d, can be answered by looking into word vector space and calculating $\mathbf{u}_b - \mathbf{u}_a + \mathbf{u}_c$, and finding the word vector that is the closest to the result.
#
# ## Your task
# Complete the missing code in this notebook. Make sure that all the functions follow the provided specification, i.e. the output of the function exactly matches the description in the docstring.
#
# We are given a text that contains $N$ unique words $\{ x_1, ..., x_N \}$. We will focus on the Skip-Gram model in which the goal is to predict the context window $S = \{ x_{i-l}, ..., x_{i-1}, x_{i+1}, ..., x_{i+l} \}$ from current word $x_i$, where $l$ is the window size.
#
# We get a word embedding $\mathbf{u}_i$ by multiplying the matrix $\mathbf{U}$ with a one-hot representation $\mathbf{x}_i$ of a word $x_i$. Then, to get output probabilities for context window, we multiply this embedding with another matrix $\mathbf{V}$ and apply softmax. The objective is to minimize the loss: $-\mathop{\mathbb{E}}[P(S|x_i;\mathbf{U}, \mathbf{V})]$.
#
# You are given a dataset with positive and negative reviews. Your task is to:
# + Construct input-output pairs corresponding to the current word and a word in the context window
# + Implement forward and backward propagation with parameter updates for Skip-Gram model
# + Train the model
# + Test it on word analogies and sentiment analysis task
#
# ## General remarks
#
# Fill in the missing code at the markers
# ```python
# ###########################
# # YOUR CODE HERE
# ###########################
# ```
# Do not add or modify any code at other places in the notebook except where otherwise explicitly stated.
# After you fill in all the missing code, restart the kernel and re-run all the cells in the notebook.
#
# The following things are **NOT** allowed:
# - Using additional `import` statements
# - Copying / reusing code from other sources (e.g. code by other students)
#
# If you plagiarise even for a single project task, you won't be eligible for the bonus this semester.

# %% [markdown]
# # 1. Load data (5 pts)
#
# We'll be working with a subset of reviews for restaurants in Las Vegas. The reviews that we'll be working with are either 1-star or 5-star.

# %%
data = np.load("task03_data.npy", allow_pickle=True).item()
reviews_1star = [[x.lower() for x in s] for s in data["reviews_1star"]]
reviews_5star = [[x.lower() for x in s] for s in data["reviews_5star"]]

# %% [markdown]
# We generate the vocabulary by taking the top 200 words by their frequency from both positive and negative sentences. We could also use the whole vocabulary, but that would be slower. Other words are represented with "unk".

# %%
corpus = reviews_1star + reviews_5star
vocabulary = [w for s in corpus for w in s]
vocabulary, counts = zip(*Counter(vocabulary).most_common(200))

# %%
corpus = [[w if w in vocabulary else 'unk' for w in s] for s in corpus]
vocabulary += ('unk',) # Add "unk" to vocabulary
counts += (sum([w == 'unk' for s in corpus for w in s]),) # Add count for "unk"

# %%
VOCABULARY_SIZE = len(vocabulary)
EMBEDDING_DIM = 32

# %%
print('Number of positive reviews:', len(reviews_1star))
print('Number of negative reviews:', len(reviews_5star))
print('Number of unique words:', VOCABULARY_SIZE)
# Out:
# Number of positive reviews: 1000
# Number of negative reviews: 2000
# Number of unique words: 201

# %% [markdown]
# You have to create two dictionaries: `word_to_ind` and `ind_to_word` so we can go from text to numerical representation and vice versa. The input into the model will be the index of the word denoting the position in the vocabulary.

# %%
"""
Implement
---------
word_to_ind: dict
    The keys are words (str) and the value is the corresponding position in the vocabulary
ind_to_word: dict
    The keys are indices (int) and the value is the corresponding word from the vocabulary
ind_to_freq: dict
    The keys are indices (int) and the value is the corresponding count in the vocabulary
"""

###########################
# YOUR CODE HERE
###########################
word_to_ind = {}
ind_to_word = {}
ind_to_freq = {}
for i in range(VOCABULARY_SIZE):
    word_to_ind.update({vocabulary[i]: i})
    ind_to_word.update({i: vocabulary[i]})
    ind_to_freq.update({i: counts[i]})

# %%
print(f'Word \"the\" is at position {word_to_ind["the"]} appearing {ind_to_freq[word_to_ind["the"]]} times')
# Should output: 
# Word "the" is at position 0 appearing 2017 times
# Out:
# Word "the" is at position 0 appearing 2017 times

# %% [markdown]
# # 2. Create word pairs (5 pts)
#
# We need all the word pairs $\{ x_i, x_j \}$, where $x_i$ is the current word and $x_j$ is from its context window. These will correspond to input-output pairs. We want them to be represented numericaly so you should use `word_to_ind` dictionary.

# %%
def get_window(sentence, window_size):
    """
    Collect all ordered word pairs from a sentence that are at most window_size apart.
    
    Parameters
    ----------
    sentence: list
        A list of words of str type forming a sentence
    window_size: int
        A positive scalar
        
    Returns
    -------
    pairs: list
        A list of tuple (word index, word index from its context) of int type
    """
    
    pairs = []

    ###########################
    # YOUR CODE HERE
    for i in range(len(sentence)):
        word = sentence[i]
        word_idx = word_to_ind[word]
        for j in range(1, window_size+1):
            if i - j >= 0:
                window_word_before = sentence[i - j]
                window_word_idx = word_to_ind[window_word_before]
                pairs.append([word_idx, window_word_idx])
            if i + j < len(sentence): 
                window_word_after = sentence[i + j]
                window_word_idx = word_to_ind[window_word_after]
                pairs.append([word_idx, window_word_idx])
    ###########################

    return pairs

# %%
data = []
for x in corpus:
    data += get_window(x, window_size=3)
data = np.array(data)

print('First 5 pairs:', data[:5].tolist())
print('Total number of pairs:', data.shape[0])
# Should output:
# First 5 pairs: [[10, 200], [10, 6], [10, 64], [200, 10], [200, 6]]
# Total number of pairs: 207462
# Out:
# First 5 pairs: [[10, 200], [10, 6], [10, 64], [200, 10], [200, 6]]
# Total number of pairs: 207462

# %% [markdown]
# We calculate a weighting score to counter the imbalance between the rare and frequent words. Rare words will be sampled more frequently. See https://arxiv.org/pdf/1310.4546.pdf

# %%
probabilities = [1 - np.sqrt(1e-3 / ind_to_freq[x]) for x in data[:,0]]
probabilities /= np.sum(probabilities)
print(probabilities[:3])
# Should output: 
# [4.8206203e-06 4.8206203e-06 4.8206203e-06]
# Out:
# [4.8206203e-06 4.8206203e-06 4.8206203e-06]

# %% [markdown]
# # 3. Model definition (55 pts)
#
# In this part you should implement forward and backward propagation together with update of the parameters i.e.:
# + One-hot encoding of the words(5 pts)
# + Softmax (5 pts)
# + Loss implementation & computation (5 pts)
# + Forward pass (15 pts)
# + Backward pass (15 pts)
# + Optimizer (10 pts)

# %%
class Embedding():
    """
    Word embedding model.

    Parameters
    ----------
    N: int
        Number of unique words in the vocabulary
    D: int
        Dimension of the word vector embedding
    """
    def __init__(self, N, D):
        self.N = N
        self.D = D

        self.ctx = None # Used to store values for backpropagation

        self.U = None
        self.V = None
        self.reset_parameters()

    def reset_parameters(self):
        """
        We initialize weight matrices U and V of dimension (D, N) and (N, D), respectively
        """
        self.ctx = None
        self.U = np.random.normal(0, np.sqrt(6. / (self.D + self.N)), (self.D, self.N))
        self.V = np.random.normal(0, np.sqrt(6. / (self.D + self.N)), (self.N, self.D))

    def one_hot(self, x, N):
        """
        Given a vector returns a matrix with rows corresponding to one-hot encoding.
        
        Parameters
        ----------
        x: array
            M-dimensional vector containing integers from [0, N - 1]
        N: int
            Number of posible classes
        
        Returns
        -------
        one_hot: array
            (N, M) matrix where each column is N-dimensional one-hot encoding of elements from x 
        """

        ###########################
        # YOUR CODE HERE
        one_hot = np.zeros([N, x.shape[0]])
        for col in range(x.shape[0]):
            for row in range(N):
                if x[col] == row:
                    one_hot[row, col] = 1
        ###########################

        assert one_hot.shape == (N, x.shape[0]), 'Incorrect one-hot embedding shape'
        return one_hot

    def softmax(self, x, axis):
        """
        Parameters
        ----------
        x: array
            A non-empty matrix of any dimension
        axis: int
            Dimension on which softmax is performed
            
        Returns
        -------
        y: array
            Matrix of same dimension as x with softmax applied to 'axis' dimension
        """
        
        # Note! You should implement a numerically stable version of softmax
        
        ###########################
        # YOUR CODE HERE
        epsilon = 1e-8 # to avoid dividing by 0
        
        x_stable = x - np.amax(x)
        
        numerator = np.exp(x_stable) + epsilon
        denominator = np.sum(numerator, axis=0)

        y = numerator/denominator


        ###########################
        
        assert x.shape == y.shape, 'Output should have the same shape is input'
        return y

    def loss(self, y, prob):
        """
        Parameters
        ----------
        y: array
            (N, M) matrix of M samples where columns are one-hot vectors for true values
        prob: array
            (N, M) column of M samples where columns are probability vectors after softmax

        Returns
        -------
        loss: int
            Cross-entropy loss calculated as: -(1 / M) * sum_i(sum_j(y_ij * log(prob_ij)))
        """

        prob = np.clip(prob, 1e-8, None)
        
        ###########################
        # YOUR CODE HERE
        N, M = y.shape
        loss = 0
        for i in range(N):
            for j in range(M):
                loss -= y[i, j] * np.log(prob[i, j])
        loss /= M
        ###########################
        
        assert isinstance(loss, float), 'Loss must be a scalar'
        return loss

    def forward(self, x, y):
        """
        Performs forward and backward propagation
        
        Parameters
        ----------
        x: array
            M-dimensional mini-batched vector containing input word indices of int type
        y: array
            Output words, same dimension and type as 'x'
            
        Returns
        -------
        loss: float
            Cross-entropy loss
        """
        
        # Input transformation
        """
        Input is represented with M-dimensional vectors
        We convert them to (N, M) matrices such that columns are one-hot 
        representations of the input
        """
        x = self.one_hot(x, self.N)
        y = self.one_hot(y, self.N)
        
        # Forward propagation
        """
        Returns
        -------
        embedding: array
            (D, M) matrix where columns are word embedding from U matrix
        logits: array
            (N, M) matrix where columns are output logits
        prob: array
            (N, M) matrix where columns are output probabilities
        """
        
        ###########################
        # YOUR CODE HERE
        # Embedding
        embedding = np.dot(self.U, x)
        
        # Logits
        logits = np.dot(self.V, embedding)
        
        # Prob
        prob = self.softmax(logits, axis=0)
        
        # Loss is already implemented below
        ###########################

        assert embedding.shape == (self.D, x.shape[1])
        assert logits.shape == (self.N, x.shape[1])
        assert prob.shape == (self.N, x.shape[1])
        
        # Save values for backpropagation
        self.ctx = (embedding, logits, prob, x, y)
        
        # Loss calculation
        loss = self.loss(y, prob)
        
        return loss
        
    def backward(self):
        """
        Given parameters from forward propagation, returns gradient of U and V.
        
        Returns
        -------
        d_V: array
            (N, D) matrix of partial derivatives of loss w.r.t. V
        d_U: array
            (D, N) matrix of partial derivatives of loss w.r.t. U
        """

        embedding, logits, prob, x, y = self.ctx

        ###########################
        # YOUR CODE HERE
        N, M = prob.shape
        D = embedding.shape[0]
        prob = np.clip(prob, 1e-8, None) # to avoid dividing by 0
        
        '''d_l_prob = 0
        for i in range(N):
            for j in range(M):
                d_l_prob -= y[i, j]/prob[i, j]
        d_l_prob /= M
        
        # d_prob_logit is false!
        d_prob_logit = prob # NxM
        
        
        
        # d_V
        d_logit_V = embedding.T # MxD
        
        d_V = d_l_prob * np.dot(d_prob_logit, d_logit_V)'''
        
        d_V = (1/M) * (prob - y) @ x.T @ self.U.T
        
        
        # d_U
        '''d_logit_embed = self.V # NxD
        
        d_embed_u = x # NxM
        
        d_U = d_l_prob * np.dot(np.dot(d_prob_logit, d_embed_u.T), d_logit_embed)
        d_U = d_U.T'''
        
        d_U = (1/M) * self.V.T @ (prob - y) @ x.T
        
        ###########################

        assert d_V.shape == (self.N, self.D)
        assert d_U.shape == (self.D, self.N)

        return { 'V': d_V, 'U': d_U }

# %%
class Optimizer():
    """
    Stochastic gradient descent with momentum optimizer.

    Parameters
    ----------
    model: object
        Model as defined above
    learning_rate: float
        Learning rate
    momentum: float (optional)
        Momentum factor (default: 0)
    """
    def __init__(self, model, learning_rate, momentum=0):
        self.model = model
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.previous = None # Previous gradients
    
    def _init_previous(self, grad):
        # Initialize previous gradients to zero
        self.previous = { k: np.zeros_like(v) for k,v in grad.items() }
    
    def step(self, grad):
        if self.previous is None:
            self._init_previous(grad)
            
        for name, dw in grad.items():
            dw_prev = self.previous[name]
            w = getattr(self.model, name)

            """
            Given weight w, previous gradients dw_prev and current 
            gradients dw, performs an update of weight w.

            Returns
            -------
            dw_new: array
                New gradients calculated as combination of previous and
                current, weighted with momentum factor.
            w_new: array
                New weights calculated with a single step of gradient
                descent using dw_new.
            """
            ###########################
            # YOUR CODE HERE
            # V, then U
            dv_or_du = grad[name]
            dw_new = self.momentum * dw_prev + (1 - self.momentum) * dv_or_du
            w_new = w - self.learning_rate * dw_new
            
            
            ###########################

            self.previous[name] = dw_new
            setattr(self.model, name, w_new)

# %% [markdown]
# ## 3.1 Gradient check
#
# The following code checks whether the updates for weights are implemented correctly. It should run without an error.

# %%
def get_loss(model, old, variable, epsilon, x, y, i, j):
    np.random.seed(123)
    model.reset_parameters() # reset weights
    
    delta = np.zeros_like(old)
    delta[i, j] = epsilon
    
    setattr(model, variable, old + delta) # change one weight by a small amount
    loss = model.forward(x, y)

    return loss

def gradient_check_for_weight(model, variable, i, j, k, l):
    x, y = np.array([i, i]), np.array([j, j]) # set input and output
    
    np.random.seed(123)
    model.reset_parameters() # reset weights

    old = getattr(model, variable)
    
    loss = model.forward(x, y)
    grad = model.backward()
    
    eps = 1e-4
    loss_positive = get_loss(model, old, variable, eps, x, y, k, l) # loss for positive change on one weight
    loss_negative = get_loss(model, old, variable, -eps, x, y, k, l) # loss for negative change on one weight
    
    true_gradient = (loss_positive - loss_negative) / 2 / eps # calculate true derivative wrt one weight

    assert abs(true_gradient - grad[variable][k, l]) < 1e-5, 'Incorrect gradient'

def gradient_check():
    N, D = VOCABULARY_SIZE, EMBEDDING_DIM
    model = Embedding(N, D)

    # check for V
    for _ in range(20):
        i, j, k = [np.random.randint(0, d) for d in [N, N, D]] # get random indices for input and weights
        gradient_check_for_weight(model, 'V', i, j, i, k)

    # check for U
    for _ in range(20):
        i, j, k = [np.random.randint(0, d) for d in [N, N, D]]
        gradient_check_for_weight(model, 'U', i, j, k, i)

    print('Gradients checked - all good!')

gradient_check()
# Out:
# Gradients checked - all good!

# %% [markdown]
# # 4. Training

# %% [markdown]
# We train our model using stochastic gradient descent. At every step we sample a mini-batch from data and update the weights.
#
# The following function samples words from data and creates mini-batches. It subsamples frequent words based on previously calculated probabilities.

# %%
rng = np.random.default_rng(123)
def get_batch(data, size, prob):
    x = rng.choice(data, size, p=prob)
    return x[:,0], x[:,1]

# %% [markdown]
# Training the model can take some time so plan accordingly.

# %%
model = Embedding(N=VOCABULARY_SIZE, D=EMBEDDING_DIM)
optim = Optimizer(model, learning_rate=1.0, momentum=0.5)

losses = []

MAX_ITERATIONS = 15000
PRINT_EVERY = 1000
BATCH_SIZE = 1000

for i in range(MAX_ITERATIONS):
    x, y = get_batch(data, BATCH_SIZE, probabilities)
    
    loss = model.forward(x, y)
    grad = model.backward()
    optim.step(grad)
    
    assert not np.isnan(loss)
    
    losses.append(loss)

    if (i + 1) % PRINT_EVERY == 0:
        print(f'Iteration: {i + 1}, Avg. training loss: {np.mean(losses[-PRINT_EVERY:]):.4f}')
# Out:
# Iteration: 1, Avg. training loss: 5.3013
# Iteration: 2, Avg. training loss: 5.2977
# Iteration: 3, Avg. training loss: 5.2675
# Iteration: 4, Avg. training loss: 5.2392
# Iteration: 5, Avg. training loss: 5.2188
# Iteration: 6, Avg. training loss: 5.1706
# Iteration: 7, Avg. training loss: 5.1269
# Iteration: 8, Avg. training loss: 5.1035
# Iteration: 9, Avg. training loss: 5.0166
# Iteration: 10, Avg. training loss: 4.9812
# Iteration: 11, Avg. training loss: 4.9183
# Iteration: 12, Avg. training loss: 4.8464
# Iteration: 13, Avg. training loss: 4.8461
# Iteration: 14, Avg. training loss: 4.7251
# Iteration: 15, Avg. training loss: 4.7361
# Iteration: 16, Avg. training loss: 4.7997
# Iteration: 17, Avg. training loss: 4.8074
# Iteration: 18, Avg. training loss: 4.7504
# Iteration: 19, Avg. training loss: 4.7324
# Iteration: 20, Avg. training loss: 4.6748
# Iteration: 21, Avg. training loss: 4.7030
# Iteration: 22, Avg. training loss: 4.6306
# Iteration: 23, Avg. training loss: 4.6083
# Iteration: 24, Avg. training loss: 4.6245
# Iteration: 25, Avg. training loss: 4.5786
# Iteration: 26, Avg. training loss: 4.6701
# Iteration: 27, Avg. training loss: 4.5133
# Iteration: 28, Avg. training loss: 4.6356
# Iteration: 29, Avg. training loss: 4.5830
# Iteration: 30, Avg. training loss: 4.5717
# Iteration: 31, Avg. training loss: 4.5328
# Iteration: 32, Avg. training loss: 4.6066
# Iteration: 33, Avg. training loss: 4.4387
# Iteration: 34, Avg. training loss: 4.4478
# Iteration: 35, Avg. training loss: 4.4506
# Iteration: 36, Avg. training loss: 4.5386
# Iteration: 37, Avg. training loss: 4.4433
# Iteration: 38, Avg. training loss: 4.4839
# Iteration: 39, Avg. training loss: 4.4360
# Iteration: 40, Avg. training loss: 4.4509
# Iteration: 41, Avg. training loss: 4.4452
# Iteration: 42, Avg. training loss: 4.4203
# Iteration: 43, Avg. training loss: 4.3722
# Iteration: 44, Avg. training loss: 4.3182
# Iteration: 45, Avg. training loss: 4.3412
# Iteration: 46, Avg. training loss: 4.4191
# Iteration: 47, Avg. training loss: 4.2802
# Iteration: 48, Avg. training loss: 4.3574
# Iteration: 49, Avg. training loss: 4.2867
# Iteration: 50, Avg. training loss: 4.3121
# Iteration: 51, Avg. training loss: 4.3139
# Iteration: 52, Avg. training loss: 4.2759
# Iteration: 53, Avg. training loss: 4.2847
# Iteration: 54, Avg. training loss: 4.2029
# Iteration: 55, Avg. training loss: 4.3038
# Iteration: 56, Avg. training loss: 4.2213
# Iteration: 57, Avg. training loss: 4.3020
# Iteration: 58, Avg. training loss: 4.2715
# Iteration: 59, Avg. training loss: 4.2393
# Iteration: 60, Avg. training loss: 4.2022
# Iteration: 61, Avg. training loss: 4.1083
# Iteration: 62, Avg. training loss: 4.2429
# Iteration: 63, Avg. training loss: 4.1973
# Iteration: 64, Avg. training loss: 4.0602
# Iteration: 65, Avg. training loss: 4.0866
# Iteration: 66, Avg. training loss: 4.1508
# Iteration: 67, Avg. training loss: 4.2903
# Iteration: 68, Avg. training loss: 4.1580
# Iteration: 69, Avg. training loss: 4.1802
# Iteration: 70, Avg. training loss: 4.2560
# Iteration: 71, Avg. training loss: 4.1395
# Iteration: 72, Avg. training loss: 4.1773
# Iteration: 73, Avg. training loss: 4.2522
# Iteration: 74, Avg. training loss: 4.2794
# Iteration: 75, Avg. training loss: 4.2329
# Iteration: 76, Avg. training loss: 4.1337
# Iteration: 77, Avg. training loss: 4.0480
# Iteration: 78, Avg. training loss: 4.1284
# Iteration: 79, Avg. training loss: 4.0355
# Iteration: 80, Avg. training loss: 4.0731
# Iteration: 81, Avg. training loss: 4.1028
# Iteration: 82, Avg. training loss: 4.0318
# Iteration: 83, Avg. training loss: 4.1315
# Iteration: 84, Avg. training loss: 4.0776
# Iteration: 85, Avg. training loss: 4.0504
# Iteration: 86, Avg. training loss: 4.0985
# Iteration: 87, Avg. training loss: 4.0512
# Iteration: 88, Avg. training loss: 4.0892
# Iteration: 89, Avg. training loss: 3.9906
# Iteration: 90, Avg. training loss: 4.1067
# Iteration: 91, Avg. training loss: 4.0130
# Iteration: 92, Avg. training loss: 3.9858
# Iteration: 93, Avg. training loss: 4.0502
# Iteration: 94, Avg. training loss: 4.0997
# Iteration: 95, Avg. training loss: 4.0013
# Iteration: 96, Avg. training loss: 3.9274
# Iteration: 97, Avg. training loss: 3.9999
# Iteration: 98, Avg. training loss: 3.9614
# Iteration: 99, Avg. training loss: 3.9752
# Iteration: 100, Avg. training loss: 3.9736
# Iteration: 101, Avg. training loss: 3.9200
# Iteration: 102, Avg. training loss: 3.9800
# Iteration: 103, Avg. training loss: 3.8666
# Iteration: 104, Avg. training loss: 3.9947
# Iteration: 105, Avg. training loss: 4.0042
# Iteration: 106, Avg. training loss: 3.9925
# Iteration: 107, Avg. training loss: 3.9659
# Iteration: 108, Avg. training loss: 3.9968
# Iteration: 109, Avg. training loss: 3.9102
# Iteration: 110, Avg. training loss: 3.8838
# Iteration: 111, Avg. training loss: 3.8470
# Iteration: 112, Avg. training loss: 3.9066
# Iteration: 113, Avg. training loss: 3.9253
# Iteration: 114, Avg. training loss: 3.9793
# Iteration: 115, Avg. training loss: 3.9448
# Iteration: 116, Avg. training loss: 4.0265
# Iteration: 117, Avg. training loss: 3.9217
# Iteration: 118, Avg. training loss: 3.9373
# Iteration: 119, Avg. training loss: 3.9227
# Iteration: 120, Avg. training loss: 3.9187
# Iteration: 121, Avg. training loss: 4.0678
# Iteration: 122, Avg. training loss: 3.8424
# Iteration: 123, Avg. training loss: 3.9756
# Iteration: 124, Avg. training loss: 3.8985
# Iteration: 125, Avg. training loss: 3.8285
# Iteration: 126, Avg. training loss: 3.7609
# Iteration: 127, Avg. training loss: 3.8148
# Iteration: 128, Avg. training loss: 3.8383
# Iteration: 129, Avg. training loss: 3.9014
# Iteration: 130, Avg. training loss: 3.8364
# Iteration: 131, Avg. training loss: 3.8915
# Iteration: 132, Avg. training loss: 3.8252
# Iteration: 133, Avg. training loss: 3.7888
# Iteration: 134, Avg. training loss: 3.8784
# Iteration: 135, Avg. training loss: 3.9373
# Iteration: 136, Avg. training loss: 3.8115
# Iteration: 137, Avg. training loss: 3.9536
# Iteration: 138, Avg. training loss: 3.8920
# Iteration: 139, Avg. training loss: 3.8971
# Iteration: 140, Avg. training loss: 3.8321
# Iteration: 141, Avg. training loss: 3.8876
# Iteration: 142, Avg. training loss: 3.8857
# Iteration: 143, Avg. training loss: 3.8758
# Iteration: 144, Avg. training loss: 3.8015
# Iteration: 145, Avg. training loss: 3.8717
# Iteration: 146, Avg. training loss: 3.8615
# Iteration: 147, Avg. training loss: 3.8796
# Iteration: 148, Avg. training loss: 3.8688
# Iteration: 149, Avg. training loss: 3.8495
# Iteration: 150, Avg. training loss: 3.7949
# Iteration: 151, Avg. training loss: 3.8900
# Iteration: 152, Avg. training loss: 3.9413
# Iteration: 153, Avg. training loss: 3.6771
# Iteration: 154, Avg. training loss: 3.7895
# Iteration: 155, Avg. training loss: 3.8620
# Iteration: 156, Avg. training loss: 3.8134
# Iteration: 157, Avg. training loss: 3.7293
# Iteration: 158, Avg. training loss: 3.8674
# Iteration: 159, Avg. training loss: 3.8665
# Iteration: 160, Avg. training loss: 3.8182
# Iteration: 161, Avg. training loss: 3.7833
# Iteration: 162, Avg. training loss: 3.8337
# Iteration: 163, Avg. training loss: 3.8873
# Iteration: 164, Avg. training loss: 3.8071
# Iteration: 165, Avg. training loss: 3.9502
# Iteration: 166, Avg. training loss: 3.8432
# Iteration: 167, Avg. training loss: 3.8833
# Iteration: 168, Avg. training loss: 3.8810
# Iteration: 169, Avg. training loss: 3.8189
# Iteration: 170, Avg. training loss: 3.7707
# Iteration: 171, Avg. training loss: 3.7783
# Iteration: 172, Avg. training loss: 3.8786
# Iteration: 173, Avg. training loss: 3.7928
# Iteration: 174, Avg. training loss: 3.7688
# Iteration: 175, Avg. training loss: 3.8547
# Iteration: 176, Avg. training loss: 3.7286
# Iteration: 177, Avg. training loss: 3.8087
# Iteration: 178, Avg. training loss: 3.8757
# Iteration: 179, Avg. training loss: 3.7336
# Iteration: 180, Avg. training loss: 3.8498
# Iteration: 181, Avg. training loss: 3.9087
# Iteration: 182, Avg. training loss: 3.7611
# Iteration: 183, Avg. training loss: 3.8309
# Iteration: 184, Avg. training loss: 3.6593
# Iteration: 185, Avg. training loss: 3.7464
# Iteration: 186, Avg. training loss: 3.6859
# Iteration: 187, Avg. training loss: 3.8028
# Iteration: 188, Avg. training loss: 3.9388
# Iteration: 189, Avg. training loss: 3.7356
# Iteration: 190, Avg. training loss: 3.8998
# Iteration: 191, Avg. training loss: 3.7369
# Iteration: 192, Avg. training loss: 3.6206
# Iteration: 193, Avg. training loss: 3.9248
# Iteration: 194, Avg. training loss: 3.6241
# Iteration: 195, Avg. training loss: 3.7750
# Iteration: 196, Avg. training loss: 3.6376
# Iteration: 197, Avg. training loss: 3.7834
# Iteration: 198, Avg. training loss: 3.8158
# Iteration: 199, Avg. training loss: 3.7944
# Iteration: 200, Avg. training loss: 3.7179
# Iteration: 201, Avg. training loss: 3.7831
# Iteration: 202, Avg. training loss: 3.8287
# Iteration: 203, Avg. training loss: 3.7777
# Iteration: 204, Avg. training loss: 3.7219
# Iteration: 205, Avg. training loss: 3.9539
# Iteration: 206, Avg. training loss: 3.6978
# Iteration: 207, Avg. training loss: 3.7552
# Iteration: 208, Avg. training loss: 3.7614
# Iteration: 209, Avg. training loss: 3.8064
# Iteration: 210, Avg. training loss: 3.7043
# Iteration: 211, Avg. training loss: 3.7267
# Iteration: 212, Avg. training loss: 3.5535
# Iteration: 213, Avg. training loss: 3.6998
# Iteration: 214, Avg. training loss: 3.6828
# Iteration: 215, Avg. training loss: 3.7365
# Iteration: 216, Avg. training loss: 3.8211
# Iteration: 217, Avg. training loss: 3.6747
# Iteration: 218, Avg. training loss: 3.9092
# Iteration: 219, Avg. training loss: 3.6366
# Iteration: 220, Avg. training loss: 3.7786
# Iteration: 221, Avg. training loss: 3.8545
# Iteration: 222, Avg. training loss: 3.6753
# Iteration: 223, Avg. training loss: 3.6636
# Iteration: 224, Avg. training loss: 3.7302
# Iteration: 225, Avg. training loss: 3.7883
# Iteration: 226, Avg. training loss: 3.7636
# Iteration: 227, Avg. training loss: 3.8078
# Iteration: 228, Avg. training loss: 3.7635
# Iteration: 229, Avg. training loss: 3.7853
# Iteration: 230, Avg. training loss: 3.7042
# Iteration: 231, Avg. training loss: 3.6486
# Iteration: 232, Avg. training loss: 3.5973
# Iteration: 233, Avg. training loss: 3.6067
# Iteration: 234, Avg. training loss: 3.6920
# Iteration: 235, Avg. training loss: 3.6887
# Iteration: 236, Avg. training loss: 3.7044
# Iteration: 237, Avg. training loss: 3.7078
# Iteration: 238, Avg. training loss: 3.7879
# Iteration: 239, Avg. training loss: 3.7293
# Iteration: 240, Avg. training loss: 3.7248
# Iteration: 241, Avg. training loss: 3.8565
# Iteration: 242, Avg. training loss: 3.6067
# Iteration: 243, Avg. training loss: 3.7410
# Iteration: 244, Avg. training loss: 3.6058
# Iteration: 245, Avg. training loss: 3.7346
# Iteration: 246, Avg. training loss: 3.7334
# Iteration: 247, Avg. training loss: 3.7849
# Iteration: 248, Avg. training loss: 3.7654
# Iteration: 249, Avg. training loss: 3.7454
# Iteration: 250, Avg. training loss: 3.6382
# Iteration: 251, Avg. training loss: 3.8335
# Iteration: 252, Avg. training loss: 3.6885
# Iteration: 253, Avg. training loss: 3.6960
# Iteration: 254, Avg. training loss: 3.8057
# Iteration: 255, Avg. training loss: 3.6198
# Iteration: 256, Avg. training loss: 3.7237
# Iteration: 257, Avg. training loss: 3.7133
# Iteration: 258, Avg. training loss: 3.6506
# Iteration: 259, Avg. training loss: 3.6248
# Iteration: 260, Avg. training loss: 3.6671
# Iteration: 261, Avg. training loss: 3.8280
# Iteration: 262, Avg. training loss: 3.8547
# Iteration: 263, Avg. training loss: 3.6042
# Iteration: 264, Avg. training loss: 3.6652
# Iteration: 265, Avg. training loss: 3.8232
# Iteration: 266, Avg. training loss: 3.6843
# Iteration: 267, Avg. training loss: 3.6981
# Iteration: 268, Avg. training loss: 3.5983
# Iteration: 269, Avg. training loss: 3.6095
# Iteration: 270, Avg. training loss: 3.7271
# Iteration: 271, Avg. training loss: 3.6848
# Iteration: 272, Avg. training loss: 3.6881
# Iteration: 273, Avg. training loss: 3.7410
# Iteration: 274, Avg. training loss: 3.7370
# Iteration: 275, Avg. training loss: 3.5708
# Iteration: 276, Avg. training loss: 3.6110
# Iteration: 277, Avg. training loss: 3.7357
# Iteration: 278, Avg. training loss: 3.7008
# Iteration: 279, Avg. training loss: 3.7862
# Iteration: 280, Avg. training loss: 3.7584
# Iteration: 281, Avg. training loss: 3.7147
# Iteration: 282, Avg. training loss: 3.6413
# Iteration: 283, Avg. training loss: 3.7433
# Iteration: 284, Avg. training loss: 3.7113
# Iteration: 285, Avg. training loss: 3.7836
# Iteration: 286, Avg. training loss: 3.6695
# Iteration: 287, Avg. training loss: 3.6567
# Iteration: 288, Avg. training loss: 3.7439
# Iteration: 289, Avg. training loss: 3.7696
# Iteration: 290, Avg. training loss: 3.6475
# Iteration: 291, Avg. training loss: 3.6567
# Iteration: 292, Avg. training loss: 3.6697
# Iteration: 293, Avg. training loss: 3.6551
# Iteration: 294, Avg. training loss: 3.7668
# Iteration: 295, Avg. training loss: 3.7032
# Iteration: 296, Avg. training loss: 3.6108
# Iteration: 297, Avg. training loss: 3.7027
# Iteration: 298, Avg. training loss: 3.6656
# Iteration: 299, Avg. training loss: 3.6366
# Iteration: 300, Avg. training loss: 3.5781
# Iteration: 301, Avg. training loss: 3.6761
# Iteration: 302, Avg. training loss: 3.5718
# Iteration: 303, Avg. training loss: 3.7170
# Iteration: 304, Avg. training loss: 3.6884
# Iteration: 305, Avg. training loss: 3.6642
# Iteration: 306, Avg. training loss: 3.6678
# Iteration: 307, Avg. training loss: 3.6584
# Iteration: 308, Avg. training loss: 3.6845
# Iteration: 309, Avg. training loss: 3.7133
# Iteration: 310, Avg. training loss: 3.6160
# Iteration: 311, Avg. training loss: 3.6919
# Iteration: 312, Avg. training loss: 3.6569
# Iteration: 313, Avg. training loss: 3.7445
# Iteration: 314, Avg. training loss: 3.7239
# Iteration: 315, Avg. training loss: 3.7510
# Iteration: 316, Avg. training loss: 3.6891
# Iteration: 317, Avg. training loss: 3.6632
# Iteration: 318, Avg. training loss: 3.6667
# Iteration: 319, Avg. training loss: 3.6340
# Iteration: 320, Avg. training loss: 3.6933
# Iteration: 321, Avg. training loss: 3.6095
# Iteration: 322, Avg. training loss: 3.6778
# Iteration: 323, Avg. training loss: 3.5363
# Iteration: 324, Avg. training loss: 3.6942
# Iteration: 325, Avg. training loss: 3.7291
# Iteration: 326, Avg. training loss: 3.6837
# Iteration: 327, Avg. training loss: 3.7661
# Iteration: 328, Avg. training loss: 3.8144
# Iteration: 329, Avg. training loss: 3.5890
# Iteration: 330, Avg. training loss: 3.7806
# Iteration: 331, Avg. training loss: 3.8598
# Iteration: 332, Avg. training loss: 3.6596
# Iteration: 333, Avg. training loss: 3.7074
# Iteration: 334, Avg. training loss: 3.7261
# Iteration: 335, Avg. training loss: 3.7659
# Iteration: 336, Avg. training loss: 3.6084
# Iteration: 337, Avg. training loss: 3.5675
# Iteration: 338, Avg. training loss: 3.7602
# Iteration: 339, Avg. training loss: 3.6151
# Iteration: 340, Avg. training loss: 3.6007
# Iteration: 341, Avg. training loss: 3.6991
# Iteration: 342, Avg. training loss: 3.7599
# Iteration: 343, Avg. training loss: 3.6816
# Iteration: 344, Avg. training loss: 3.6033
# Iteration: 345, Avg. training loss: 3.7524
# Iteration: 346, Avg. training loss: 3.5956
# Iteration: 347, Avg. training loss: 3.6554
# Iteration: 348, Avg. training loss: 3.6002
# Iteration: 349, Avg. training loss: 3.5390
# Iteration: 350, Avg. training loss: 3.5608
# Iteration: 351, Avg. training loss: 3.6707
# Iteration: 352, Avg. training loss: 3.6203
# Iteration: 353, Avg. training loss: 3.5897
# Iteration: 354, Avg. training loss: 3.6243
# Iteration: 355, Avg. training loss: 3.6835
# Iteration: 356, Avg. training loss: 3.7462
# Iteration: 357, Avg. training loss: 3.6821
# Iteration: 358, Avg. training loss: 3.5242
# Iteration: 359, Avg. training loss: 3.6840
# Iteration: 360, Avg. training loss: 3.5510
# Iteration: 361, Avg. training loss: 3.5330
# Iteration: 362, Avg. training loss: 3.5736
# Iteration: 363, Avg. training loss: 3.6093
# Iteration: 364, Avg. training loss: 3.6581
# Iteration: 365, Avg. training loss: 3.5591
# Iteration: 366, Avg. training loss: 3.6494
# Iteration: 367, Avg. training loss: 3.7862
# Iteration: 368, Avg. training loss: 3.6646
# Iteration: 369, Avg. training loss: 3.5142
# Iteration: 370, Avg. training loss: 3.5389
# Iteration: 371, Avg. training loss: 3.6595
# Iteration: 372, Avg. training loss: 3.5360
# Iteration: 373, Avg. training loss: 3.6530
# Iteration: 374, Avg. training loss: 3.5220
# Iteration: 375, Avg. training loss: 3.5473
# Iteration: 376, Avg. training loss: 3.6069
# Iteration: 377, Avg. training loss: 3.5922
# Iteration: 378, Avg. training loss: 3.5898
# Iteration: 379, Avg. training loss: 3.4950
# Iteration: 380, Avg. training loss: 3.5623
# Iteration: 381, Avg. training loss: 3.5677
# Iteration: 382, Avg. training loss: 3.6946
# Iteration: 383, Avg. training loss: 3.7068
# Iteration: 384, Avg. training loss: 3.5614
# Iteration: 385, Avg. training loss: 3.6409
# Iteration: 386, Avg. training loss: 3.6679
# Iteration: 387, Avg. training loss: 3.6328
# Iteration: 388, Avg. training loss: 3.6545
# Iteration: 389, Avg. training loss: 3.6474
# Iteration: 390, Avg. training loss: 3.6682
# Iteration: 391, Avg. training loss: 3.6232
# Iteration: 392, Avg. training loss: 3.6362
# Iteration: 393, Avg. training loss: 3.6056
# Iteration: 394, Avg. training loss: 3.6198
# Iteration: 395, Avg. training loss: 3.5714
# Iteration: 396, Avg. training loss: 3.6999
# Iteration: 397, Avg. training loss: 3.7037
# Iteration: 398, Avg. training loss: 3.6688
# Iteration: 399, Avg. training loss: 3.6438
# Iteration: 400, Avg. training loss: 3.5285
# Iteration: 401, Avg. training loss: 3.5339
# Iteration: 402, Avg. training loss: 3.6505
# Iteration: 403, Avg. training loss: 3.6816
# Iteration: 404, Avg. training loss: 3.5818
# Iteration: 405, Avg. training loss: 3.6066
# Iteration: 406, Avg. training loss: 3.7111
# Iteration: 407, Avg. training loss: 3.5908
# Iteration: 408, Avg. training loss: 3.6089
# Iteration: 409, Avg. training loss: 3.6782
# Iteration: 410, Avg. training loss: 3.5877
# Iteration: 411, Avg. training loss: 3.7257
# Iteration: 412, Avg. training loss: 3.5747
# Iteration: 413, Avg. training loss: 3.6481
# Iteration: 414, Avg. training loss: 3.6707
# Iteration: 415, Avg. training loss: 3.6805
# Iteration: 416, Avg. training loss: 3.5998
# Iteration: 417, Avg. training loss: 3.6651
# Iteration: 418, Avg. training loss: 3.6840
# Iteration: 419, Avg. training loss: 3.7546
# Iteration: 420, Avg. training loss: 3.7021
# Iteration: 421, Avg. training loss: 3.6984
# Iteration: 422, Avg. training loss: 3.6079
# Iteration: 423, Avg. training loss: 3.6025
# Iteration: 424, Avg. training loss: 3.6739
# Iteration: 425, Avg. training loss: 3.5414
# Iteration: 426, Avg. training loss: 3.7475
# Iteration: 427, Avg. training loss: 3.6396
# Iteration: 428, Avg. training loss: 3.6668
# Iteration: 429, Avg. training loss: 3.6336
# Iteration: 430, Avg. training loss: 3.5804
# Iteration: 431, Avg. training loss: 3.6261
# Iteration: 432, Avg. training loss: 3.6359
# Iteration: 433, Avg. training loss: 3.5627
# Iteration: 434, Avg. training loss: 3.5401
# Iteration: 435, Avg. training loss: 3.5162
# Iteration: 436, Avg. training loss: 3.5860
# Iteration: 437, Avg. training loss: 3.6146
# Iteration: 438, Avg. training loss: 3.5941
# Iteration: 439, Avg. training loss: 3.4925
# Iteration: 440, Avg. training loss: 3.6534
# Iteration: 441, Avg. training loss: 3.5453
# Iteration: 442, Avg. training loss: 3.6214
# Iteration: 443, Avg. training loss: 3.5964
# Iteration: 444, Avg. training loss: 3.4541
# Iteration: 445, Avg. training loss: 3.7360
# Iteration: 446, Avg. training loss: 3.6931
# Iteration: 447, Avg. training loss: 3.5772
# Iteration: 448, Avg. training loss: 3.6990
# Iteration: 449, Avg. training loss: 3.4693
# Iteration: 450, Avg. training loss: 3.6453
# Iteration: 451, Avg. training loss: 3.7264
# Iteration: 452, Avg. training loss: 3.6439
# Iteration: 453, Avg. training loss: 3.6068
# Iteration: 454, Avg. training loss: 3.5113
# Iteration: 455, Avg. training loss: 3.5452
# Iteration: 456, Avg. training loss: 3.5591
# Iteration: 457, Avg. training loss: 3.5729
# Iteration: 458, Avg. training loss: 3.5950
# Iteration: 459, Avg. training loss: 3.7434
# Iteration: 460, Avg. training loss: 3.6898
# Iteration: 461, Avg. training loss: 3.6789
# Iteration: 462, Avg. training loss: 3.6381
# Iteration: 463, Avg. training loss: 3.6256
# Iteration: 464, Avg. training loss: 3.6393
# Iteration: 465, Avg. training loss: 3.5388
# Iteration: 466, Avg. training loss: 3.6490
# Iteration: 467, Avg. training loss: 3.6170
# Iteration: 468, Avg. training loss: 3.6406
# Iteration: 469, Avg. training loss: 3.7158
# Iteration: 470, Avg. training loss: 3.5680
# Iteration: 471, Avg. training loss: 3.6043
# Iteration: 472, Avg. training loss: 3.5519
# Iteration: 473, Avg. training loss: 3.5811
# Iteration: 474, Avg. training loss: 3.7283
# Iteration: 475, Avg. training loss: 3.6754
# Iteration: 476, Avg. training loss: 3.5613
# Iteration: 477, Avg. training loss: 3.5756
# Iteration: 478, Avg. training loss: 3.6509
# Iteration: 479, Avg. training loss: 3.6877
# Iteration: 480, Avg. training loss: 3.6056
# Iteration: 481, Avg. training loss: 3.5352
# Iteration: 482, Avg. training loss: 3.6405
# Iteration: 483, Avg. training loss: 3.5986
# Iteration: 484, Avg. training loss: 3.4655
# Iteration: 485, Avg. training loss: 3.5846
# Iteration: 486, Avg. training loss: 3.6333
# Iteration: 487, Avg. training loss: 3.6048
# Iteration: 488, Avg. training loss: 3.6278
# Iteration: 489, Avg. training loss: 3.6936
# Iteration: 490, Avg. training loss: 3.5527
# Iteration: 491, Avg. training loss: 3.6307
# Iteration: 492, Avg. training loss: 3.5654
# Iteration: 493, Avg. training loss: 3.7034
# Iteration: 494, Avg. training loss: 3.5123
# Iteration: 495, Avg. training loss: 3.6298
# Iteration: 496, Avg. training loss: 3.6421
# Iteration: 497, Avg. training loss: 3.6241
# Iteration: 498, Avg. training loss: 3.6343
# Iteration: 499, Avg. training loss: 3.7426
# Iteration: 500, Avg. training loss: 3.5071
# Iteration: 501, Avg. training loss: 3.6575
# Iteration: 502, Avg. training loss: 3.5345
# Iteration: 503, Avg. training loss: 3.7410
# Iteration: 504, Avg. training loss: 3.6398
# Iteration: 505, Avg. training loss: 3.6206
# Iteration: 506, Avg. training loss: 3.5662
# Iteration: 507, Avg. training loss: 3.6177
# Iteration: 508, Avg. training loss: 3.6172
# Iteration: 509, Avg. training loss: 3.5036
# Iteration: 510, Avg. training loss: 3.5476
# Iteration: 511, Avg. training loss: 3.6775
# Iteration: 512, Avg. training loss: 3.5751
# Iteration: 513, Avg. training loss: 3.6712
# Iteration: 514, Avg. training loss: 3.5711
# Iteration: 515, Avg. training loss: 3.5854
# Iteration: 516, Avg. training loss: 3.6393
# Iteration: 517, Avg. training loss: 3.5842
# Iteration: 518, Avg. training loss: 3.5724
# Iteration: 519, Avg. training loss: 3.6500
# Iteration: 520, Avg. training loss: 3.5726
# Iteration: 521, Avg. training loss: 3.5944
# Iteration: 522, Avg. training loss: 3.5537
# Iteration: 523, Avg. training loss: 3.5623
# Iteration: 524, Avg. training loss: 3.5263
# Iteration: 525, Avg. training loss: 3.6044
# Iteration: 526, Avg. training loss: 3.6795
# Iteration: 527, Avg. training loss: 3.6413
# Iteration: 528, Avg. training loss: 3.4482
# Iteration: 529, Avg. training loss: 3.6890
# Iteration: 530, Avg. training loss: 3.7240
# Iteration: 531, Avg. training loss: 3.6042
# Iteration: 532, Avg. training loss: 3.6356
# Iteration: 533, Avg. training loss: 3.7195
# Iteration: 534, Avg. training loss: 3.6169
# Iteration: 535, Avg. training loss: 3.6063
# Iteration: 536, Avg. training loss: 3.6000
# Iteration: 537, Avg. training loss: 3.6012
# Iteration: 538, Avg. training loss: 3.6124
# Iteration: 539, Avg. training loss: 3.5960
# Iteration: 540, Avg. training loss: 3.4969
# Iteration: 541, Avg. training loss: 3.6307
# Iteration: 542, Avg. training loss: 3.5498
# Iteration: 543, Avg. training loss: 3.6331
# Iteration: 544, Avg. training loss: 3.5304
# Iteration: 545, Avg. training loss: 3.5425
# Iteration: 546, Avg. training loss: 3.6723
# Iteration: 547, Avg. training loss: 3.6111
# Iteration: 548, Avg. training loss: 3.6364
# Iteration: 549, Avg. training loss: 3.5225
# Iteration: 550, Avg. training loss: 3.5407
# Iteration: 551, Avg. training loss: 3.7076
# Iteration: 552, Avg. training loss: 3.6401
# Iteration: 553, Avg. training loss: 3.5951
# Iteration: 554, Avg. training loss: 3.6420
# Iteration: 555, Avg. training loss: 3.5741
# Iteration: 556, Avg. training loss: 3.4833
# Iteration: 557, Avg. training loss: 3.4235
# Iteration: 558, Avg. training loss: 3.5288
# Iteration: 559, Avg. training loss: 3.5018
# Iteration: 560, Avg. training loss: 3.6051
# Iteration: 561, Avg. training loss: 3.6143
# Iteration: 562, Avg. training loss: 3.6582
# Iteration: 563, Avg. training loss: 3.5770
# Iteration: 564, Avg. training loss: 3.7208
# Iteration: 565, Avg. training loss: 3.5623
# Iteration: 566, Avg. training loss: 3.6030
# Iteration: 567, Avg. training loss: 3.6282
# Iteration: 568, Avg. training loss: 3.6324
# Iteration: 569, Avg. training loss: 3.6290
# Iteration: 570, Avg. training loss: 3.4286
# Iteration: 571, Avg. training loss: 3.5546
# Iteration: 572, Avg. training loss: 3.5996
# Iteration: 573, Avg. training loss: 3.6078
# Iteration: 574, Avg. training loss: 3.6605
# Iteration: 575, Avg. training loss: 3.6187
# Iteration: 576, Avg. training loss: 3.4792
# Iteration: 577, Avg. training loss: 3.6511
# Iteration: 578, Avg. training loss: 3.6203
# Iteration: 579, Avg. training loss: 3.6094
# Iteration: 580, Avg. training loss: 3.6516
# Iteration: 581, Avg. training loss: 3.5630
# Iteration: 582, Avg. training loss: 3.6709
# Iteration: 583, Avg. training loss: 3.5678
# Iteration: 584, Avg. training loss: 3.5857
# Iteration: 585, Avg. training loss: 3.5861
# Iteration: 586, Avg. training loss: 3.5811
# Iteration: 587, Avg. training loss: 3.6507
# Iteration: 588, Avg. training loss: 3.6297
# Iteration: 589, Avg. training loss: 3.5356
# Iteration: 590, Avg. training loss: 3.6268
# Iteration: 591, Avg. training loss: 3.5850
# Iteration: 592, Avg. training loss: 3.6621
# Iteration: 593, Avg. training loss: 3.6024
# Iteration: 594, Avg. training loss: 3.6062
# Iteration: 595, Avg. training loss: 3.5863
# Iteration: 596, Avg. training loss: 3.6501
# Iteration: 597, Avg. training loss: 3.5663
# Iteration: 598, Avg. training loss: 3.6215
# Iteration: 599, Avg. training loss: 3.6306
# Iteration: 600, Avg. training loss: 3.4499
# Iteration: 601, Avg. training loss: 3.5507
# Iteration: 602, Avg. training loss: 3.5888
# Iteration: 603, Avg. training loss: 3.6477
# Iteration: 604, Avg. training loss: 3.6992
# Iteration: 605, Avg. training loss: 3.5331
# Iteration: 606, Avg. training loss: 3.6575
# Iteration: 607, Avg. training loss: 3.5427
# Iteration: 608, Avg. training loss: 3.7144
# Iteration: 609, Avg. training loss: 3.5620
# Iteration: 610, Avg. training loss: 3.5947
# Iteration: 611, Avg. training loss: 3.5955
# Iteration: 612, Avg. training loss: 3.5946
# Iteration: 613, Avg. training loss: 3.5329
# Iteration: 614, Avg. training loss: 3.6302
# Iteration: 615, Avg. training loss: 3.5495
# Iteration: 616, Avg. training loss: 3.5621
# Iteration: 617, Avg. training loss: 3.5436
# Iteration: 618, Avg. training loss: 3.5436
# Iteration: 619, Avg. training loss: 3.7410
# Iteration: 620, Avg. training loss: 3.5471
# Iteration: 621, Avg. training loss: 3.5487
# Iteration: 622, Avg. training loss: 3.4828
# Iteration: 623, Avg. training loss: 3.5896
# Iteration: 624, Avg. training loss: 3.6130
# Iteration: 625, Avg. training loss: 3.5775
# Iteration: 626, Avg. training loss: 3.5477
# Iteration: 627, Avg. training loss: 3.4788
# Iteration: 628, Avg. training loss: 3.6722
# Iteration: 629, Avg. training loss: 3.6221
# Iteration: 630, Avg. training loss: 3.5673
# Iteration: 631, Avg. training loss: 3.6055
# Iteration: 632, Avg. training loss: 3.5572
# Iteration: 633, Avg. training loss: 3.6597
# Iteration: 634, Avg. training loss: 3.6455
# Iteration: 635, Avg. training loss: 3.4731
# Iteration: 636, Avg. training loss: 3.6449
# Iteration: 637, Avg. training loss: 3.6566
# Iteration: 638, Avg. training loss: 3.6390
# Iteration: 639, Avg. training loss: 3.7051
# Iteration: 640, Avg. training loss: 3.7010
# Iteration: 641, Avg. training loss: 3.7075
# Iteration: 642, Avg. training loss: 3.6027
# Iteration: 643, Avg. training loss: 3.6225
# Iteration: 644, Avg. training loss: 3.6224
# Iteration: 645, Avg. training loss: 3.6578
# Iteration: 646, Avg. training loss: 3.5622
# Iteration: 647, Avg. training loss: 3.6053
# Iteration: 648, Avg. training loss: 3.6583
# Iteration: 649, Avg. training loss: 3.6380
# Iteration: 650, Avg. training loss: 3.5207
# Iteration: 651, Avg. training loss: 3.6206
# Iteration: 652, Avg. training loss: 3.6533
# Iteration: 653, Avg. training loss: 3.5528
# Iteration: 654, Avg. training loss: 3.6442
# Iteration: 655, Avg. training loss: 3.5191
# Iteration: 656, Avg. training loss: 3.6583
# Iteration: 657, Avg. training loss: 3.6177
# Iteration: 658, Avg. training loss: 3.5488
# Iteration: 659, Avg. training loss: 3.6374
# Iteration: 660, Avg. training loss: 3.6451
# Iteration: 661, Avg. training loss: 3.5933
# Iteration: 662, Avg. training loss: 3.5321
# Iteration: 663, Avg. training loss: 3.6291
# Iteration: 664, Avg. training loss: 3.6214
# Iteration: 665, Avg. training loss: 3.6371
# Iteration: 666, Avg. training loss: 3.4676
# Iteration: 667, Avg. training loss: 3.6681
# Iteration: 668, Avg. training loss: 3.5247
# Iteration: 669, Avg. training loss: 3.5563
# Iteration: 670, Avg. training loss: 3.5307
# Iteration: 671, Avg. training loss: 3.7039
# Iteration: 672, Avg. training loss: 3.6788
# Iteration: 673, Avg. training loss: 3.6397
# Iteration: 674, Avg. training loss: 3.5556
# Iteration: 675, Avg. training loss: 3.7005
# Iteration: 676, Avg. training loss: 3.5589
# Iteration: 677, Avg. training loss: 3.5829
# Iteration: 678, Avg. training loss: 3.5761
# Iteration: 679, Avg. training loss: 3.4697
# Iteration: 680, Avg. training loss: 3.5722
# Iteration: 681, Avg. training loss: 3.6021
# Iteration: 682, Avg. training loss: 3.5660
# Iteration: 683, Avg. training loss: 3.6467
# Iteration: 684, Avg. training loss: 3.6177
# Iteration: 685, Avg. training loss: 3.5615
# Iteration: 686, Avg. training loss: 3.4835
# Iteration: 687, Avg. training loss: 3.7175
# Iteration: 688, Avg. training loss: 3.5502
# Iteration: 689, Avg. training loss: 3.7268
# Iteration: 690, Avg. training loss: 3.6140
# Iteration: 691, Avg. training loss: 3.5739
# Iteration: 692, Avg. training loss: 3.6638
# Iteration: 693, Avg. training loss: 3.6878
# Iteration: 694, Avg. training loss: 3.5306
# Iteration: 695, Avg. training loss: 3.5315
# Iteration: 696, Avg. training loss: 3.6707
# Iteration: 697, Avg. training loss: 3.6052
# Iteration: 698, Avg. training loss: 3.5111
# Iteration: 699, Avg. training loss: 3.5209
# Iteration: 700, Avg. training loss: 3.5802
# Iteration: 701, Avg. training loss: 3.5732
# Iteration: 702, Avg. training loss: 3.5688
# Iteration: 703, Avg. training loss: 3.7612
# Iteration: 704, Avg. training loss: 3.5932
# Iteration: 705, Avg. training loss: 3.6360
# Iteration: 706, Avg. training loss: 3.7412
# Iteration: 707, Avg. training loss: 3.5874
# Iteration: 708, Avg. training loss: 3.4428
# Iteration: 709, Avg. training loss: 3.5667
# Iteration: 710, Avg. training loss: 3.5960
# Iteration: 711, Avg. training loss: 3.6479
# Iteration: 712, Avg. training loss: 3.5865
# Iteration: 713, Avg. training loss: 3.5775
# Iteration: 714, Avg. training loss: 3.6126
# Iteration: 715, Avg. training loss: 3.5780
# Iteration: 716, Avg. training loss: 3.6082
# Iteration: 717, Avg. training loss: 3.6498
# Iteration: 718, Avg. training loss: 3.5679
# Iteration: 719, Avg. training loss: 3.5733
# Iteration: 720, Avg. training loss: 3.5005
# Iteration: 721, Avg. training loss: 3.6213
# Iteration: 722, Avg. training loss: 3.6259
# Iteration: 723, Avg. training loss: 3.5191
# Iteration: 724, Avg. training loss: 3.5960
# Iteration: 725, Avg. training loss: 3.6490
# Iteration: 726, Avg. training loss: 3.5712
# Iteration: 727, Avg. training loss: 3.6060
# Iteration: 728, Avg. training loss: 3.6087
# Iteration: 729, Avg. training loss: 3.6504
# Iteration: 730, Avg. training loss: 3.5483
# Iteration: 731, Avg. training loss: 3.6293
# Iteration: 732, Avg. training loss: 3.6611
# Iteration: 733, Avg. training loss: 3.6202
# Iteration: 734, Avg. training loss: 3.5059
# Iteration: 735, Avg. training loss: 3.5946
# Iteration: 736, Avg. training loss: 3.5387
# Iteration: 737, Avg. training loss: 3.6390
# Iteration: 738, Avg. training loss: 3.6806
# Iteration: 739, Avg. training loss: 3.5532
# Iteration: 740, Avg. training loss: 3.5580
# Iteration: 741, Avg. training loss: 3.6879
# Iteration: 742, Avg. training loss: 3.6550
# Iteration: 743, Avg. training loss: 3.4900
# Iteration: 744, Avg. training loss: 3.6719
# Iteration: 745, Avg. training loss: 3.5299
# Iteration: 746, Avg. training loss: 3.6068
# Iteration: 747, Avg. training loss: 3.5896
# Iteration: 748, Avg. training loss: 3.6880
# Iteration: 749, Avg. training loss: 3.5262
# Iteration: 750, Avg. training loss: 3.5995
# Iteration: 751, Avg. training loss: 3.6328
# Iteration: 752, Avg. training loss: 3.5203
# Iteration: 753, Avg. training loss: 3.5632
# Iteration: 754, Avg. training loss: 3.7437
# Iteration: 755, Avg. training loss: 3.4639
# Iteration: 756, Avg. training loss: 3.3617
# Iteration: 757, Avg. training loss: 3.6207
# Iteration: 758, Avg. training loss: 3.6416
# Iteration: 759, Avg. training loss: 3.6440
# Iteration: 760, Avg. training loss: 3.6469
# Iteration: 761, Avg. training loss: 3.5228
# Iteration: 762, Avg. training loss: 3.6153
# Iteration: 763, Avg. training loss: 3.6816
# Iteration: 764, Avg. training loss: 3.5990
# Iteration: 765, Avg. training loss: 3.6131
# Iteration: 766, Avg. training loss: 3.6957
# Iteration: 767, Avg. training loss: 3.5426
# Iteration: 768, Avg. training loss: 3.6288
# Iteration: 769, Avg. training loss: 3.5409
# Iteration: 770, Avg. training loss: 3.6222
# Iteration: 771, Avg. training loss: 3.6185
# Iteration: 772, Avg. training loss: 3.7634
# Iteration: 773, Avg. training loss: 3.5731
# Iteration: 774, Avg. training loss: 3.6010
# Iteration: 775, Avg. training loss: 3.7132
# Iteration: 776, Avg. training loss: 3.5791
# Iteration: 777, Avg. training loss: 3.4303
# Iteration: 778, Avg. training loss: 3.6804
# Iteration: 779, Avg. training loss: 3.5508
# Iteration: 780, Avg. training loss: 3.5784
# Iteration: 781, Avg. training loss: 3.6965
# Iteration: 782, Avg. training loss: 3.5930
# Iteration: 783, Avg. training loss: 3.8144
# Iteration: 784, Avg. training loss: 3.5824
# Iteration: 785, Avg. training loss: 3.5441
# Iteration: 786, Avg. training loss: 3.6029
# Iteration: 787, Avg. training loss: 3.6116
# Iteration: 788, Avg. training loss: 3.5622
# Iteration: 789, Avg. training loss: 3.5553
# Iteration: 790, Avg. training loss: 3.6794
# Iteration: 791, Avg. training loss: 3.5471
# Iteration: 792, Avg. training loss: 3.6480
# Iteration: 793, Avg. training loss: 3.5912
# Iteration: 794, Avg. training loss: 3.6018
# Iteration: 795, Avg. training loss: 3.5007
# Iteration: 796, Avg. training loss: 3.5172
# Iteration: 797, Avg. training loss: 3.6619
# Iteration: 798, Avg. training loss: 3.5810
# Iteration: 799, Avg. training loss: 3.5907
# Iteration: 800, Avg. training loss: 3.6765
# Iteration: 801, Avg. training loss: 3.5399
# Iteration: 802, Avg. training loss: 3.5813
# Iteration: 803, Avg. training loss: 3.7134
# Iteration: 804, Avg. training loss: 3.7000
# Iteration: 805, Avg. training loss: 3.5829
# Iteration: 806, Avg. training loss: 3.5045
# Iteration: 807, Avg. training loss: 3.6196
# Iteration: 808, Avg. training loss: 3.6319
# Iteration: 809, Avg. training loss: 3.5518
# Iteration: 810, Avg. training loss: 3.6166
# Iteration: 811, Avg. training loss: 3.5382
# Iteration: 812, Avg. training loss: 3.5801
# Iteration: 813, Avg. training loss: 3.6249
# Iteration: 814, Avg. training loss: 3.7026
# Iteration: 815, Avg. training loss: 3.5860
# Iteration: 816, Avg. training loss: 3.7179
# Iteration: 817, Avg. training loss: 3.6399
# Iteration: 818, Avg. training loss: 3.5224
# Iteration: 819, Avg. training loss: 3.6411
# Iteration: 820, Avg. training loss: 3.6902
# Iteration: 821, Avg. training loss: 3.6019
# Iteration: 822, Avg. training loss: 3.6038
# Iteration: 823, Avg. training loss: 3.6414
# Iteration: 824, Avg. training loss: 3.6244
# Iteration: 825, Avg. training loss: 3.5518
# Iteration: 826, Avg. training loss: 3.6609
# Iteration: 827, Avg. training loss: 3.6176
# Iteration: 828, Avg. training loss: 3.6198
# Iteration: 829, Avg. training loss: 3.5703
# Iteration: 830, Avg. training loss: 3.5710
# Iteration: 831, Avg. training loss: 3.6827
# Iteration: 832, Avg. training loss: 3.6475
# Iteration: 833, Avg. training loss: 3.4877
# Iteration: 834, Avg. training loss: 3.4618
# Iteration: 835, Avg. training loss: 3.5759
# Iteration: 836, Avg. training loss: 3.6123
# Iteration: 837, Avg. training loss: 3.6096
# Iteration: 838, Avg. training loss: 3.5564
# Iteration: 839, Avg. training loss: 3.3878
# Iteration: 840, Avg. training loss: 3.5590
# Iteration: 841, Avg. training loss: 3.5576
# Iteration: 842, Avg. training loss: 3.6130
# Iteration: 843, Avg. training loss: 3.6604
# Iteration: 844, Avg. training loss: 3.6296
# Iteration: 845, Avg. training loss: 3.7067
# Iteration: 846, Avg. training loss: 3.6567
# Iteration: 847, Avg. training loss: 3.5816
# Iteration: 848, Avg. training loss: 3.5533
# Iteration: 849, Avg. training loss: 3.6284
# Iteration: 850, Avg. training loss: 3.5724
# Iteration: 851, Avg. training loss: 3.6254
# Iteration: 852, Avg. training loss: 3.5883
# Iteration: 853, Avg. training loss: 3.6503
# Iteration: 854, Avg. training loss: 3.6193
# Iteration: 855, Avg. training loss: 3.5467
# Iteration: 856, Avg. training loss: 3.5731
# Iteration: 857, Avg. training loss: 3.7334
# Iteration: 858, Avg. training loss: 3.6451
# Iteration: 859, Avg. training loss: 3.6329
# Iteration: 860, Avg. training loss: 3.6165
# Iteration: 861, Avg. training loss: 3.4633
# Iteration: 862, Avg. training loss: 3.4366
# Iteration: 863, Avg. training loss: 3.5656
# Iteration: 864, Avg. training loss: 3.5525
# Iteration: 865, Avg. training loss: 3.6208
# Iteration: 866, Avg. training loss: 3.5360
# Iteration: 867, Avg. training loss: 3.6093
# Iteration: 868, Avg. training loss: 3.4708
# Iteration: 869, Avg. training loss: 3.6115
# Iteration: 870, Avg. training loss: 3.6805
# Iteration: 871, Avg. training loss: 3.4861
# Iteration: 872, Avg. training loss: 3.6345
# Iteration: 873, Avg. training loss: 3.6180
# Iteration: 874, Avg. training loss: 3.5891
# Iteration: 875, Avg. training loss: 3.5974
# Iteration: 876, Avg. training loss: 3.5886
# Iteration: 877, Avg. training loss: 3.4991
# Iteration: 878, Avg. training loss: 3.6874
# Iteration: 879, Avg. training loss: 3.4764
# Iteration: 880, Avg. training loss: 3.6058
# Iteration: 881, Avg. training loss: 3.4694
# Iteration: 882, Avg. training loss: 3.5595
# Iteration: 883, Avg. training loss: 3.5986
# Iteration: 884, Avg. training loss: 3.5379
# Iteration: 885, Avg. training loss: 3.6183
# Iteration: 886, Avg. training loss: 3.4811
# Iteration: 887, Avg. training loss: 3.5226
# Iteration: 888, Avg. training loss: 3.5475
# Iteration: 889, Avg. training loss: 3.5085
# Iteration: 890, Avg. training loss: 3.5244
# Iteration: 891, Avg. training loss: 3.6714
# Iteration: 892, Avg. training loss: 3.5924
# Iteration: 893, Avg. training loss: 3.6792
# Iteration: 894, Avg. training loss: 3.6805
# Iteration: 895, Avg. training loss: 3.6495
# Iteration: 896, Avg. training loss: 3.5864
# Iteration: 897, Avg. training loss: 3.5836
# Iteration: 898, Avg. training loss: 3.6937
# Iteration: 899, Avg. training loss: 3.5665
# Iteration: 900, Avg. training loss: 3.5228
# Iteration: 901, Avg. training loss: 3.4204
# Iteration: 902, Avg. training loss: 3.6120
# Iteration: 903, Avg. training loss: 3.6911
# Iteration: 904, Avg. training loss: 3.5691
# Iteration: 905, Avg. training loss: 3.6377
# Iteration: 906, Avg. training loss: 3.5630
# Iteration: 907, Avg. training loss: 3.6544
# Iteration: 908, Avg. training loss: 3.6194
# Iteration: 909, Avg. training loss: 3.5619
# Iteration: 910, Avg. training loss: 3.4751
# Iteration: 911, Avg. training loss: 3.6953
# Iteration: 912, Avg. training loss: 3.6499
# Iteration: 913, Avg. training loss: 3.6587
# Iteration: 914, Avg. training loss: 3.5964
# Iteration: 915, Avg. training loss: 3.5821
# Iteration: 916, Avg. training loss: 3.5951
# Iteration: 917, Avg. training loss: 3.5250
# Iteration: 918, Avg. training loss: 3.6333
# Iteration: 919, Avg. training loss: 3.5738
# Iteration: 920, Avg. training loss: 3.5766
# Iteration: 921, Avg. training loss: 3.6726
# Iteration: 922, Avg. training loss: 3.5919
# Iteration: 923, Avg. training loss: 3.7061
# Iteration: 924, Avg. training loss: 3.5945
# Iteration: 925, Avg. training loss: 3.6712
# Iteration: 926, Avg. training loss: 3.4615
# Iteration: 927, Avg. training loss: 3.5943
# Iteration: 928, Avg. training loss: 3.7067
# Iteration: 929, Avg. training loss: 3.6817
# Iteration: 930, Avg. training loss: 3.5998
# Iteration: 931, Avg. training loss: 3.5501
# Iteration: 932, Avg. training loss: 3.4704
# Iteration: 933, Avg. training loss: 3.5583
# Iteration: 934, Avg. training loss: 3.4958
# Iteration: 935, Avg. training loss: 3.6087
# Iteration: 936, Avg. training loss: 3.6468
# Iteration: 937, Avg. training loss: 3.5509
# Iteration: 938, Avg. training loss: 3.4834
# Iteration: 939, Avg. training loss: 3.6055
# Iteration: 940, Avg. training loss: 3.6302
# Iteration: 941, Avg. training loss: 3.5832
# Iteration: 942, Avg. training loss: 3.6486
# Iteration: 943, Avg. training loss: 3.6584
# Iteration: 944, Avg. training loss: 3.5182
# Iteration: 945, Avg. training loss: 3.6291
# Iteration: 946, Avg. training loss: 3.6072
# Iteration: 947, Avg. training loss: 3.6047
# Iteration: 948, Avg. training loss: 3.5378
# Iteration: 949, Avg. training loss: 3.6870
# Iteration: 950, Avg. training loss: 3.5849
# Iteration: 951, Avg. training loss: 3.6561
# Iteration: 952, Avg. training loss: 3.6414
# Iteration: 953, Avg. training loss: 3.5579
# Iteration: 954, Avg. training loss: 3.5597
# Iteration: 955, Avg. training loss: 3.5964
# Iteration: 956, Avg. training loss: 3.6111
# Iteration: 957, Avg. training loss: 3.6552
# Iteration: 958, Avg. training loss: 3.5912
# Iteration: 959, Avg. training loss: 3.6536
# Iteration: 960, Avg. training loss: 3.5944
# Iteration: 961, Avg. training loss: 3.5790
# Iteration: 962, Avg. training loss: 3.6324
# Iteration: 963, Avg. training loss: 3.5353
# Iteration: 964, Avg. training loss: 3.6413
# Iteration: 965, Avg. training loss: 3.6023
# Iteration: 966, Avg. training loss: 3.5528
# Iteration: 967, Avg. training loss: 3.6162
# Iteration: 968, Avg. training loss: 3.4248
# Iteration: 969, Avg. training loss: 3.6100
# Iteration: 970, Avg. training loss: 3.6186
# Iteration: 971, Avg. training loss: 3.6224
# Iteration: 972, Avg. training loss: 3.5353
# Iteration: 973, Avg. training loss: 3.5011
# Iteration: 974, Avg. training loss: 3.4122
# Iteration: 975, Avg. training loss: 3.6319
# Iteration: 976, Avg. training loss: 3.5690
# Iteration: 977, Avg. training loss: 3.6257
# Iteration: 978, Avg. training loss: 3.6266
# Iteration: 979, Avg. training loss: 3.5975
# Iteration: 980, Avg. training loss: 3.6033
# Iteration: 981, Avg. training loss: 3.6270
# Iteration: 982, Avg. training loss: 3.5429
# Iteration: 983, Avg. training loss: 3.6634
# Iteration: 984, Avg. training loss: 3.6116
# Iteration: 985, Avg. training loss: 3.6039
# Iteration: 986, Avg. training loss: 3.7809
# Iteration: 987, Avg. training loss: 3.5537
# Iteration: 988, Avg. training loss: 3.6497
# Iteration: 989, Avg. training loss: 3.4819
# Iteration: 990, Avg. training loss: 3.6622
# Iteration: 991, Avg. training loss: 3.5010
# Iteration: 992, Avg. training loss: 3.6255
# Iteration: 993, Avg. training loss: 3.6065
# Iteration: 994, Avg. training loss: 3.6079
# Iteration: 995, Avg. training loss: 3.5317
# Iteration: 996, Avg. training loss: 3.5781
# Iteration: 997, Avg. training loss: 3.5726
# Iteration: 998, Avg. training loss: 3.5192
# Iteration: 999, Avg. training loss: 3.6352
# Iteration: 1000, Avg. training loss: 3.4943
# Iteration: 1001, Avg. training loss: 3.4845
# Iteration: 1002, Avg. training loss: 3.6547
# Iteration: 1003, Avg. training loss: 3.6527
# Iteration: 1004, Avg. training loss: 3.4993
# Iteration: 1005, Avg. training loss: 3.5586
# Iteration: 1006, Avg. training loss: 3.5598
# Iteration: 1007, Avg. training loss: 3.5659
# Iteration: 1008, Avg. training loss: 3.6043
# Iteration: 1009, Avg. training loss: 3.5793
# Iteration: 1010, Avg. training loss: 3.5709
# Iteration: 1011, Avg. training loss: 3.7049
# Iteration: 1012, Avg. training loss: 3.6589
# Iteration: 1013, Avg. training loss: 3.5351
# Iteration: 1014, Avg. training loss: 3.7518
# Iteration: 1015, Avg. training loss: 3.6745
# Iteration: 1016, Avg. training loss: 3.5490
# Iteration: 1017, Avg. training loss: 3.5727
# Iteration: 1018, Avg. training loss: 3.5761
# Iteration: 1019, Avg. training loss: 3.6517
# Iteration: 1020, Avg. training loss: 3.6759
# Iteration: 1021, Avg. training loss: 3.5511
# Iteration: 1022, Avg. training loss: 3.6003
# Iteration: 1023, Avg. training loss: 3.6144
# Iteration: 1024, Avg. training loss: 3.5825
# Iteration: 1025, Avg. training loss: 3.6796
# Iteration: 1026, Avg. training loss: 3.6897
# Iteration: 1027, Avg. training loss: 3.5963
# Iteration: 1028, Avg. training loss: 3.6589
# Iteration: 1029, Avg. training loss: 3.6329
# Iteration: 1030, Avg. training loss: 3.4796
# Iteration: 1031, Avg. training loss: 3.5875
# Iteration: 1032, Avg. training loss: 3.6427
# Iteration: 1033, Avg. training loss: 3.5261
# Iteration: 1034, Avg. training loss: 3.5565
# Iteration: 1035, Avg. training loss: 3.5463
# Iteration: 1036, Avg. training loss: 3.5727
# Iteration: 1037, Avg. training loss: 3.5356
# Iteration: 1038, Avg. training loss: 3.5813
# Iteration: 1039, Avg. training loss: 3.6437
# Iteration: 1040, Avg. training loss: 3.5803
# Iteration: 1041, Avg. training loss: 3.5402
# Iteration: 1042, Avg. training loss: 3.4833
# Iteration: 1043, Avg. training loss: 3.6194
# Iteration: 1044, Avg. training loss: 3.4972
# Iteration: 1045, Avg. training loss: 3.7474
# Iteration: 1046, Avg. training loss: 3.5661
# Iteration: 1047, Avg. training loss: 3.6205
# Iteration: 1048, Avg. training loss: 3.5893
# Iteration: 1049, Avg. training loss: 3.6223
# Iteration: 1050, Avg. training loss: 3.5616
# Iteration: 1051, Avg. training loss: 3.4825
# Iteration: 1052, Avg. training loss: 3.5874
# Iteration: 1053, Avg. training loss: 3.6341
# Iteration: 1054, Avg. training loss: 3.6365
# Iteration: 1055, Avg. training loss: 3.5076
# Iteration: 1056, Avg. training loss: 3.5963
# Iteration: 1057, Avg. training loss: 3.6076
# Iteration: 1058, Avg. training loss: 3.5085
# Iteration: 1059, Avg. training loss: 3.6058
# Iteration: 1060, Avg. training loss: 3.5666
# Iteration: 1061, Avg. training loss: 3.6261
# Iteration: 1062, Avg. training loss: 3.5355
# Iteration: 1063, Avg. training loss: 3.6425
# Iteration: 1064, Avg. training loss: 3.5914
# Iteration: 1065, Avg. training loss: 3.5824
# Iteration: 1066, Avg. training loss: 3.6253
# Iteration: 1067, Avg. training loss: 3.5912
# Iteration: 1068, Avg. training loss: 3.5154
# Iteration: 1069, Avg. training loss: 3.6243
# Iteration: 1070, Avg. training loss: 3.3554
# Iteration: 1071, Avg. training loss: 3.5898
# Iteration: 1072, Avg. training loss: 3.5581
# Iteration: 1073, Avg. training loss: 3.7681
# Iteration: 1074, Avg. training loss: 3.6286
# Iteration: 1075, Avg. training loss: 3.6273
# Iteration: 1076, Avg. training loss: 3.5985
# Iteration: 1077, Avg. training loss: 3.5478
# Iteration: 1078, Avg. training loss: 3.6671
# Iteration: 1079, Avg. training loss: 3.5498
# Iteration: 1080, Avg. training loss: 3.7754
# Iteration: 1081, Avg. training loss: 3.6155
# Iteration: 1082, Avg. training loss: 3.5193
# Iteration: 1083, Avg. training loss: 3.4892
# Iteration: 1084, Avg. training loss: 3.7327
# Iteration: 1085, Avg. training loss: 3.5306
# Iteration: 1086, Avg. training loss: 3.5169
# Iteration: 1087, Avg. training loss: 3.5302
# Iteration: 1088, Avg. training loss: 3.5173
# Iteration: 1089, Avg. training loss: 3.6390
# Iteration: 1090, Avg. training loss: 3.6109
# Iteration: 1091, Avg. training loss: 3.6185
# Iteration: 1092, Avg. training loss: 3.5702
# Iteration: 1093, Avg. training loss: 3.6710
# Iteration: 1094, Avg. training loss: 3.5098
# Iteration: 1095, Avg. training loss: 3.5880
# Iteration: 1096, Avg. training loss: 3.4418
# Iteration: 1097, Avg. training loss: 3.5747
# Iteration: 1098, Avg. training loss: 3.5470
# Iteration: 1099, Avg. training loss: 3.7071
# Iteration: 1100, Avg. training loss: 3.6641
# Iteration: 1101, Avg. training loss: 3.5710
# Iteration: 1102, Avg. training loss: 3.6059
# Iteration: 1103, Avg. training loss: 3.6015
# Iteration: 1104, Avg. training loss: 3.6172
# Iteration: 1105, Avg. training loss: 3.5271
# Iteration: 1106, Avg. training loss: 3.5849
# Iteration: 1107, Avg. training loss: 3.5389
# Iteration: 1108, Avg. training loss: 3.5331
# Iteration: 1109, Avg. training loss: 3.4779
# Iteration: 1110, Avg. training loss: 3.4950
# Iteration: 1111, Avg. training loss: 3.5837
# Iteration: 1112, Avg. training loss: 3.5698
# Iteration: 1113, Avg. training loss: 3.5779
# Iteration: 1114, Avg. training loss: 3.5927
# Iteration: 1115, Avg. training loss: 3.7263
# Iteration: 1116, Avg. training loss: 3.5992
# ...
# Iteration: 14646, Avg. training loss: 3.5180
# Iteration: 14647, Avg. training loss: 3.4316
# Iteration: 14648, Avg. training loss: 3.5434
# Iteration: 14649, Avg. training loss: 3.5490
# Iteration: 14650, Avg. training loss: 3.5565
# Iteration: 14651, Avg. training loss: 3.5154
# Iteration: 14652, Avg. training loss: 3.3046
# Iteration: 14653, Avg. training loss: 3.4003
# Iteration: 14654, Avg. training loss: 3.3485
# Iteration: 14655, Avg. training loss: 3.4533
# Iteration: 14656, Avg. training loss: 3.5226
# Iteration: 14657, Avg. training loss: 3.5962
# Iteration: 14658, Avg. training loss: 3.4087
# Iteration: 14659, Avg. training loss: 3.4808
# Iteration: 14660, Avg. training loss: 3.5419
# Iteration: 14661, Avg. training loss: 3.5658
# Iteration: 14662, Avg. training loss: 3.4214
# Iteration: 14663, Avg. training loss: 3.4172
# Iteration: 14664, Avg. training loss: 3.4368
# Iteration: 14665, Avg. training loss: 3.5104
# Iteration: 14666, Avg. training loss: 3.4474
# Iteration: 14667, Avg. training loss: 3.5294
# Iteration: 14668, Avg. training loss: 3.4542
# Iteration: 14669, Avg. training loss: 3.4280
# Iteration: 14670, Avg. training loss: 3.3232
# Iteration: 14671, Avg. training loss: 3.4564
# Iteration: 14672, Avg. training loss: 3.4435
# Iteration: 14673, Avg. training loss: 3.4975
# Iteration: 14674, Avg. training loss: 3.6068
# Iteration: 14675, Avg. training loss: 3.5265
# Iteration: 14676, Avg. training loss: 3.3514
# Iteration: 14677, Avg. training loss: 3.4878
# Iteration: 14678, Avg. training loss: 3.3093
# Iteration: 14679, Avg. training loss: 3.5338
# Iteration: 14680, Avg. training loss: 3.4155
# Iteration: 14681, Avg. training loss: 3.4682
# Iteration: 14682, Avg. training loss: 3.4595
# Iteration: 14683, Avg. training loss: 3.3781
# Iteration: 14684, Avg. training loss: 3.5460
# Iteration: 14685, Avg. training loss: 3.6246
# Iteration: 14686, Avg. training loss: 3.5409
# Iteration: 14687, Avg. training loss: 3.4458
# Iteration: 14688, Avg. training loss: 3.5276
# Iteration: 14689, Avg. training loss: 3.3885
# Iteration: 14690, Avg. training loss: 3.5286
# Iteration: 14691, Avg. training loss: 3.5586
# Iteration: 14692, Avg. training loss: 3.4707
# Iteration: 14693, Avg. training loss: 3.4670
# Iteration: 14694, Avg. training loss: 3.6150
# Iteration: 14695, Avg. training loss: 3.4810
# Iteration: 14696, Avg. training loss: 3.5756
# Iteration: 14697, Avg. training loss: 3.5584
# Iteration: 14698, Avg. training loss: 3.5029
# Iteration: 14699, Avg. training loss: 3.4580
# Iteration: 14700, Avg. training loss: 3.3777
# Iteration: 14701, Avg. training loss: 3.5406
# Iteration: 14702, Avg. training loss: 3.3530
# Iteration: 14703, Avg. training loss: 3.4586
# Iteration: 14704, Avg. training loss: 3.4709
# Iteration: 14705, Avg. training loss: 3.4546
# Iteration: 14706, Avg. training loss: 3.5917
# Iteration: 14707, Avg. training loss: 3.5061
# Iteration: 14708, Avg. training loss: 3.3988
# Iteration: 14709, Avg. training loss: 3.5054
# Iteration: 14710, Avg. training loss: 3.6059
# Iteration: 14711, Avg. training loss: 3.3847
# Iteration: 14712, Avg. training loss: 3.4403
# Iteration: 14713, Avg. training loss: 3.4686
# Iteration: 14714, Avg. training loss: 3.4687
# Iteration: 14715, Avg. training loss: 3.5332
# Iteration: 14716, Avg. training loss: 3.4504
# Iteration: 14717, Avg. training loss: 3.4335
# Iteration: 14718, Avg. training loss: 3.5043
# Iteration: 14719, Avg. training loss: 3.5334
# Iteration: 14720, Avg. training loss: 3.5479
# Iteration: 14721, Avg. training loss: 3.6091
# Iteration: 14722, Avg. training loss: 3.4960
# Iteration: 14723, Avg. training loss: 3.4033
# Iteration: 14724, Avg. training loss: 3.5503
# Iteration: 14725, Avg. training loss: 3.4502
# Iteration: 14726, Avg. training loss: 3.4726
# Iteration: 14727, Avg. training loss: 3.5268
# Iteration: 14728, Avg. training loss: 3.4245
# Iteration: 14729, Avg. training loss: 3.4046
# Iteration: 14730, Avg. training loss: 3.5082
# Iteration: 14731, Avg. training loss: 3.5123
# Iteration: 14732, Avg. training loss: 3.5583
# Iteration: 14733, Avg. training loss: 3.3931
# Iteration: 14734, Avg. training loss: 3.4885
# Iteration: 14735, Avg. training loss: 3.5288
# Iteration: 14736, Avg. training loss: 3.4560
# Iteration: 14737, Avg. training loss: 3.3935
# Iteration: 14738, Avg. training loss: 3.4848
# Iteration: 14739, Avg. training loss: 3.5396
# Iteration: 14740, Avg. training loss: 3.4145
# Iteration: 14741, Avg. training loss: 3.5074
# Iteration: 14742, Avg. training loss: 3.5904
# Iteration: 14743, Avg. training loss: 3.4299
# Iteration: 14744, Avg. training loss: 3.5715
# Iteration: 14745, Avg. training loss: 3.5283
# Iteration: 14746, Avg. training loss: 3.5621
# Iteration: 14747, Avg. training loss: 3.3854
# Iteration: 14748, Avg. training loss: 3.3913
# Iteration: 14749, Avg. training loss: 3.4815
# Iteration: 14750, Avg. training loss: 3.4616
# Iteration: 14751, Avg. training loss: 3.4636
# Iteration: 14752, Avg. training loss: 3.5286
# Iteration: 14753, Avg. training loss: 3.4614
# Iteration: 14754, Avg. training loss: 3.4625
# Iteration: 14755, Avg. training loss: 3.4083
# Iteration: 14756, Avg. training loss: 3.5016
# Iteration: 14757, Avg. training loss: 3.2789
# Iteration: 14758, Avg. training loss: 3.6047
# Iteration: 14759, Avg. training loss: 3.4624
# Iteration: 14760, Avg. training loss: 3.4674
# Iteration: 14761, Avg. training loss: 3.4735
# Iteration: 14762, Avg. training loss: 3.5081
# Iteration: 14763, Avg. training loss: 3.5478
# Iteration: 14764, Avg. training loss: 3.5453
# Iteration: 14765, Avg. training loss: 3.5694
# Iteration: 14766, Avg. training loss: 3.5099
# Iteration: 14767, Avg. training loss: 3.4429
# Iteration: 14768, Avg. training loss: 3.4635
# Iteration: 14769, Avg. training loss: 3.4724
# Iteration: 14770, Avg. training loss: 3.3742
# Iteration: 14771, Avg. training loss: 3.4297
# Iteration: 14772, Avg. training loss: 3.3654
# Iteration: 14773, Avg. training loss: 3.5244
# Iteration: 14774, Avg. training loss: 3.5682
# Iteration: 14775, Avg. training loss: 3.5598
# Iteration: 14776, Avg. training loss: 3.5343
# Iteration: 14777, Avg. training loss: 3.5573
# Iteration: 14778, Avg. training loss: 3.5337
# Iteration: 14779, Avg. training loss: 3.3555
# Iteration: 14780, Avg. training loss: 3.4263
# Iteration: 14781, Avg. training loss: 3.5175
# Iteration: 14782, Avg. training loss: 3.5063
# Iteration: 14783, Avg. training loss: 3.5101
# Iteration: 14784, Avg. training loss: 3.5136
# Iteration: 14785, Avg. training loss: 3.3916
# Iteration: 14786, Avg. training loss: 3.6256
# Iteration: 14787, Avg. training loss: 3.5541
# Iteration: 14788, Avg. training loss: 3.5257
# Iteration: 14789, Avg. training loss: 3.4893
# Iteration: 14790, Avg. training loss: 3.5148
# Iteration: 14791, Avg. training loss: 3.5318
# Iteration: 14792, Avg. training loss: 3.5460
# Iteration: 14793, Avg. training loss: 3.3976
# Iteration: 14794, Avg. training loss: 3.4548
# Iteration: 14795, Avg. training loss: 3.4960
# Iteration: 14796, Avg. training loss: 3.5229
# Iteration: 14797, Avg. training loss: 3.4528
# Iteration: 14798, Avg. training loss: 3.4747
# Iteration: 14799, Avg. training loss: 3.4265
# Iteration: 14800, Avg. training loss: 3.5133
# Iteration: 14801, Avg. training loss: 3.4422
# Iteration: 14802, Avg. training loss: 3.4911
# Iteration: 14803, Avg. training loss: 3.5127
# Iteration: 14804, Avg. training loss: 3.3899
# Iteration: 14805, Avg. training loss: 3.5173
# Iteration: 14806, Avg. training loss: 3.4746
# Iteration: 14807, Avg. training loss: 3.3762
# Iteration: 14808, Avg. training loss: 3.4666
# Iteration: 14809, Avg. training loss: 3.4818
# Iteration: 14810, Avg. training loss: 3.4130
# Iteration: 14811, Avg. training loss: 3.5005
# Iteration: 14812, Avg. training loss: 3.4586
# Iteration: 14813, Avg. training loss: 3.5385
# Iteration: 14814, Avg. training loss: 3.3991
# Iteration: 14815, Avg. training loss: 3.3695
# Iteration: 14816, Avg. training loss: 3.4503
# Iteration: 14817, Avg. training loss: 3.5385
# Iteration: 14818, Avg. training loss: 3.5590
# Iteration: 14819, Avg. training loss: 3.4345
# Iteration: 14820, Avg. training loss: 3.4556
# Iteration: 14821, Avg. training loss: 3.4763
# Iteration: 14822, Avg. training loss: 3.4710
# Iteration: 14823, Avg. training loss: 3.4104
# Iteration: 14824, Avg. training loss: 3.5470
# Iteration: 14825, Avg. training loss: 3.4426
# Iteration: 14826, Avg. training loss: 3.5851
# Iteration: 14827, Avg. training loss: 3.3894
# Iteration: 14828, Avg. training loss: 3.4331
# Iteration: 14829, Avg. training loss: 3.4636
# Iteration: 14830, Avg. training loss: 3.4665
# Iteration: 14831, Avg. training loss: 3.4639
# Iteration: 14832, Avg. training loss: 3.4632
# Iteration: 14833, Avg. training loss: 3.3706
# Iteration: 14834, Avg. training loss: 3.6345
# Iteration: 14835, Avg. training loss: 3.5060
# Iteration: 14836, Avg. training loss: 3.3004
# Iteration: 14837, Avg. training loss: 3.5994
# Iteration: 14838, Avg. training loss: 3.5554
# Iteration: 14839, Avg. training loss: 3.5330
# Iteration: 14840, Avg. training loss: 3.4800
# Iteration: 14841, Avg. training loss: 3.5403
# Iteration: 14842, Avg. training loss: 3.3564
# Iteration: 14843, Avg. training loss: 3.4866
# Iteration: 14844, Avg. training loss: 3.5317
# Iteration: 14845, Avg. training loss: 3.4881
# Iteration: 14846, Avg. training loss: 3.4579
# Iteration: 14847, Avg. training loss: 3.5948
# Iteration: 14848, Avg. training loss: 3.4681
# Iteration: 14849, Avg. training loss: 3.5259
# Iteration: 14850, Avg. training loss: 3.4531
# Iteration: 14851, Avg. training loss: 3.4024
# Iteration: 14852, Avg. training loss: 3.4504
# Iteration: 14853, Avg. training loss: 3.5070
# Iteration: 14854, Avg. training loss: 3.5043
# Iteration: 14855, Avg. training loss: 3.4494
# Iteration: 14856, Avg. training loss: 3.4643
# Iteration: 14857, Avg. training loss: 3.5145
# Iteration: 14858, Avg. training loss: 3.4559
# Iteration: 14859, Avg. training loss: 3.5972
# Iteration: 14860, Avg. training loss: 3.4792
# Iteration: 14861, Avg. training loss: 3.4807
# Iteration: 14862, Avg. training loss: 3.5745
# Iteration: 14863, Avg. training loss: 3.5274
# Iteration: 14864, Avg. training loss: 3.4054
# Iteration: 14865, Avg. training loss: 3.3806
# Iteration: 14866, Avg. training loss: 3.5039
# Iteration: 14867, Avg. training loss: 3.4916
# Iteration: 14868, Avg. training loss: 3.5141
# Iteration: 14869, Avg. training loss: 3.4390
# Iteration: 14870, Avg. training loss: 3.4333
# Iteration: 14871, Avg. training loss: 3.5383
# Iteration: 14872, Avg. training loss: 3.3932
# Iteration: 14873, Avg. training loss: 3.4402
# Iteration: 14874, Avg. training loss: 3.4565
# Iteration: 14875, Avg. training loss: 3.4938
# Iteration: 14876, Avg. training loss: 3.4726
# Iteration: 14877, Avg. training loss: 3.5354
# Iteration: 14878, Avg. training loss: 3.5298
# Iteration: 14879, Avg. training loss: 3.5341
# Iteration: 14880, Avg. training loss: 3.5111
# Iteration: 14881, Avg. training loss: 3.5035
# Iteration: 14882, Avg. training loss: 3.5136
# Iteration: 14883, Avg. training loss: 3.5088
# Iteration: 14884, Avg. training loss: 3.5630
# Iteration: 14885, Avg. training loss: 3.4902
# Iteration: 14886, Avg. training loss: 3.5004
# Iteration: 14887, Avg. training loss: 3.4070
# Iteration: 14888, Avg. training loss: 3.4912
# Iteration: 14889, Avg. training loss: 3.5183
# Iteration: 14890, Avg. training loss: 3.3910
# Iteration: 14891, Avg. training loss: 3.4516
# Iteration: 14892, Avg. training loss: 3.5939
# Iteration: 14893, Avg. training loss: 3.4049
# Iteration: 14894, Avg. training loss: 3.4264
# Iteration: 14895, Avg. training loss: 3.6000
# Iteration: 14896, Avg. training loss: 3.3972
# Iteration: 14897, Avg. training loss: 3.4694
# Iteration: 14898, Avg. training loss: 3.4425
# Iteration: 14899, Avg. training loss: 3.4070
# Iteration: 14900, Avg. training loss: 3.4881
# Iteration: 14901, Avg. training loss: 3.5659
# Iteration: 14902, Avg. training loss: 3.5730
# Iteration: 14903, Avg. training loss: 3.5082
# Iteration: 14904, Avg. training loss: 3.4951
# Iteration: 14905, Avg. training loss: 3.5978
# Iteration: 14906, Avg. training loss: 3.4258
# Iteration: 14907, Avg. training loss: 3.5110
# Iteration: 14908, Avg. training loss: 3.4825
# Iteration: 14909, Avg. training loss: 3.4050
# Iteration: 14910, Avg. training loss: 3.5534
# Iteration: 14911, Avg. training loss: 3.4644
# Iteration: 14912, Avg. training loss: 3.3289
# Iteration: 14913, Avg. training loss: 3.4748
# Iteration: 14914, Avg. training loss: 3.5885
# Iteration: 14915, Avg. training loss: 3.5172
# Iteration: 14916, Avg. training loss: 3.5079
# Iteration: 14917, Avg. training loss: 3.4729
# Iteration: 14918, Avg. training loss: 3.4793
# Iteration: 14919, Avg. training loss: 3.4411
# Iteration: 14920, Avg. training loss: 3.4106
# Iteration: 14921, Avg. training loss: 3.5629
# Iteration: 14922, Avg. training loss: 3.6448
# Iteration: 14923, Avg. training loss: 3.4841
# Iteration: 14924, Avg. training loss: 3.4102
# Iteration: 14925, Avg. training loss: 3.5521
# Iteration: 14926, Avg. training loss: 3.4249
# Iteration: 14927, Avg. training loss: 3.4761
# Iteration: 14928, Avg. training loss: 3.4516
# Iteration: 14929, Avg. training loss: 3.5108
# Iteration: 14930, Avg. training loss: 3.4401
# Iteration: 14931, Avg. training loss: 3.6155
# Iteration: 14932, Avg. training loss: 3.3580
# Iteration: 14933, Avg. training loss: 3.5941
# Iteration: 14934, Avg. training loss: 3.4766
# Iteration: 14935, Avg. training loss: 3.3736
# Iteration: 14936, Avg. training loss: 3.5266
# Iteration: 14937, Avg. training loss: 3.3110
# Iteration: 14938, Avg. training loss: 3.5967
# Iteration: 14939, Avg. training loss: 3.4984
# Iteration: 14940, Avg. training loss: 3.6172
# Iteration: 14941, Avg. training loss: 3.5701
# Iteration: 14942, Avg. training loss: 3.3329
# Iteration: 14943, Avg. training loss: 3.5039
# Iteration: 14944, Avg. training loss: 3.5310
# Iteration: 14945, Avg. training loss: 3.4332
# Iteration: 14946, Avg. training loss: 3.5650
# Iteration: 14947, Avg. training loss: 3.4947
# Iteration: 14948, Avg. training loss: 3.5913
# Iteration: 14949, Avg. training loss: 3.5204
# Iteration: 14950, Avg. training loss: 3.6149
# Iteration: 14951, Avg. training loss: 3.4561
# Iteration: 14952, Avg. training loss: 3.5382
# Iteration: 14953, Avg. training loss: 3.3740
# Iteration: 14954, Avg. training loss: 3.4854
# Iteration: 14955, Avg. training loss: 3.3977
# Iteration: 14956, Avg. training loss: 3.4145
# Iteration: 14957, Avg. training loss: 3.4945
# Iteration: 14958, Avg. training loss: 3.5321
# Iteration: 14959, Avg. training loss: 3.5160
# Iteration: 14960, Avg. training loss: 3.4439
# Iteration: 14961, Avg. training loss: 3.4916
# Iteration: 14962, Avg. training loss: 3.3589
# Iteration: 14963, Avg. training loss: 3.3442
# Iteration: 14964, Avg. training loss: 3.4502
# Iteration: 14965, Avg. training loss: 3.5322
# Iteration: 14966, Avg. training loss: 3.4659
# Iteration: 14967, Avg. training loss: 3.4697
# Iteration: 14968, Avg. training loss: 3.4714
# Iteration: 14969, Avg. training loss: 3.6184
# Iteration: 14970, Avg. training loss: 3.5222
# Iteration: 14971, Avg. training loss: 3.3679
# Iteration: 14972, Avg. training loss: 3.5061
# Iteration: 14973, Avg. training loss: 3.6056
# Iteration: 14974, Avg. training loss: 3.5451
# Iteration: 14975, Avg. training loss: 3.4984
# Iteration: 14976, Avg. training loss: 3.4012
# Iteration: 14977, Avg. training loss: 3.3913
# Iteration: 14978, Avg. training loss: 3.5417
# Iteration: 14979, Avg. training loss: 3.5775
# Iteration: 14980, Avg. training loss: 3.5024
# Iteration: 14981, Avg. training loss: 3.5033
# Iteration: 14982, Avg. training loss: 3.5051
# Iteration: 14983, Avg. training loss: 3.5461
# Iteration: 14984, Avg. training loss: 3.4024
# Iteration: 14985, Avg. training loss: 3.5087
# Iteration: 14986, Avg. training loss: 3.5976
# Iteration: 14987, Avg. training loss: 3.4962
# Iteration: 14988, Avg. training loss: 3.6117
# Iteration: 14989, Avg. training loss: 3.5109
# Iteration: 14990, Avg. training loss: 3.5305
# Iteration: 14991, Avg. training loss: 3.4737
# Iteration: 14992, Avg. training loss: 3.4222
# Iteration: 14993, Avg. training loss: 3.4925
# Iteration: 14994, Avg. training loss: 3.5809
# Iteration: 14995, Avg. training loss: 3.5558
# Iteration: 14996, Avg. training loss: 3.3179
# Iteration: 14997, Avg. training loss: 3.4031
# Iteration: 14998, Avg. training loss: 3.6161
# Iteration: 14999, Avg. training loss: 3.4142
# Iteration: 15000, Avg. training loss: 3.3687

# %% [markdown]
# The embedding matrix is given by $\mathbf{U}^T$, where the $i$th row is the vector for $i$th word in the vocabulary.

# %%
emb_matrix = model.U.T

# %% [markdown]
# # 5. Analogies (5 pts)
#
# As mentioned before, vectors can keep some language properties like analogies. Given a relation a:b and a query c, we can find d such that c:d follows the same relation. We hope to find d by using vector operations. In this case, finding the real word vector $\mathbf{u}_d$ closest to $\mathbf{u}_b - \mathbf{u}_a + \mathbf{u}_c$ gives us d.
#
# **Note that the quality of the analy results is not expected to be excellent.**

# %%
triplets = [['is', 'was', 'were'], ['lunch', 'day', 'night'], ['i', 'my', 'your']]

for triplet in triplets:
    a, b, d = triplet

    """
    Returns
    
    Example: Paris (a) is to France (b) as _____ (c) is to Germany (d)
    
    -------
    result: array
        The embedding vector for word (c): w_a - w_b + w_d
    """

    ###########################
    # YOUR CODE HERE
    a_ind = word_to_ind[a]
    b_ind = word_to_ind[b]
    d_ind = word_to_ind[d]
    
    w_a = emb_matrix[a_ind, :]
    w_b = emb_matrix[b_ind, :]
    w_d = emb_matrix[d_ind, :]
    
    result = w_a - w_b + w_d
    ###########################

    distances = [spatial.distance.cosine(x, result) for x in emb_matrix]
    candidates = [ind_to_word[i] for i in np.argsort(distances)]
    candidates = [x for x in candidates if x not in [a, b, d]][:5]

    print(f'`{a}` is to `{b}` as [{", ".join(candidates)}] is to `{d}`')
# Out:
# `is` is to `was` as [are, rice, sauce, way, do] is to `were`
# `lunch` is to `day` as [dinner, great, experience, salad, what] is to `night`
# `i` is to `my` as [you, what, don't, not, if] is to `your`
